# %% [markdown]
# # Comparison of GCP's PII detection tools vs Presidio
#
# In this notebook we evaluate the PII detection capabilities offered by GCP DLP against Presidio.
# To avoid sending sensitive Mozilla data through GCP DLP, we run the evaluation using the public AOL search dataset (see [prepare-aol-data.ipynb](./prepare-aol-data.ipynb)) for preprocessing steps.
#
# __[Presidio](https://microsoft.github.io/presidio/)__
# - Open-source PII handling toolkit from Microsoft
# - Offers detection of a decent range of PII entities using a combination of pattern matching and public entity recognition models (spaCy)
# - Main shortcoming is that it doesn't offer detection of street addresses, which DLP does
# - Running locally, it is quite slow (10K queries per minute for numeric PII). This may be related to the fact that the main `analyze` function does not run in batch mode, and must be called separately for each query string. We'll need to evaluate further whether it is fast enough for production.
#
#
# __[GCP DLP](https://cloud.google.com/dlp/docs/how-to)__
# - Closed-source offering in the GCP ecosystem
# - Offers detection of a broad range of PII entities, including street addresses and a long list of global ID number formats
# - To use, a request containing the query must be made to its REST API. There is a Python client library which wraps the issuance of requests and processing of responses.
# - As the API backend can be updated at any time, results may not be exactly the same from one run to the next
# - In our evaluations, it was about 10x faster than Presidio (~100K queries in <1 min). It can process text in batches subject to limitations on number of records and total data size.
# - For a production deployment, we will need to investigate the policy/legal implications of sending our data through this additional API, as well as performance (eg. latency). There is also an additional [cost](https://cloud.google.com/dlp/pricing) for using the API (~$2-3/GB).
# - It offers integration with BigQuery, so another option could be to use it as part of a separate sanitization pipeline for internal data, as opposed to live querying.

# %% [markdown]
# ## Setup for GCP DLP
#
# This documents the steps needed to set up access to DLP for testing (more details [here](https://cloud.google.com/dlp/docs/inspect-sensitive-text)). These have already been completed and do not need to be repeated.
#
# 1. Set up [prototype GCP project](https://docs.telemetry.mozilla.org/cookbooks/gcp-projects.html): `search-sanitization-dev`
# 2. Enable the DLP API in the console
# 3. Create service account & key: `suggest-test-dlp`
# 4. Activate service account with CLI:
# ```bash
# gcloud auth activate-service-account \
#     suggest-test-dlp@search-sanitization-dev.iam.gserviceaccount.com \
#     --key-file=<abs_path_to_key>
# ```
#
# ## Running this notebook
#
# In order to run this notebook, first install the client libraries into the environment:
# ```bash
# pip install -r https://raw.githubusercontent.com/googleapis/python-dlp/main/samples/snippets/requirements.txt
# ```
#
# The GCP credentials must be specified in the environment.
# One way to do this is on starting the Jupyter server:
# ```bash
# GOOGLE_APPLICATION_CREDENTIALS=path/to/file jupyter notebook ...
# ```

# %%
# Sibling import
import sys
sys.path.insert(0, "../src")

# %%
import pandas as pd
from IPython.display import display

from suggest_search_tools import sanitization_lib

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.show_dimensions", True)

# %%
# Dataset of raw search queries
AOL_QUERIES_CSV = "../assets/aol_queries.csv.gz"
# DataFrame subset for numeric evaluation with inspection results
NUMERIC_INSPECTED_PKL = "./aol_numeric_inspected.pkl"
# Small manually labeled subset for numeric evaluation
NUMERIC_LABELED_PKL = "../assets/aol_numeric_labeled.pkl"

# %% [markdown]
# As a test set, we use queries pulled from the AOL search dataset.

# %%
aol_df = pd.read_csv(AOL_QUERIES_CSV)

# %%
print(f"Num queries: {len(aol_df):,}")
# Out:
# Num queries: 1,216,584

# %%
aol_df
# Out:
#                                                                      query  \
# 0                                              & bayshoredermatology group
# 1                                                                  & order
# 2                                      & secrets hidden in our childish li
# 3        & wg dj n x m iw un x1 vk e qe g w ' 1 g n k nm o o j w q. qb ; -
# 4                                                     &c91904my yahoo mail
# ...                                                                    ...
# 1216579                                                       ÷nenßOn()ßf÷
# 1216580                                                    ÷÷÷ (OG·O=f ±·n
# 1216581                                                            ø â áí'
# 1216582                                                             ùèõáíö
# 1216583                                                        üíûçôñó ñùü
#
#          has_num
# 0          False
# 1          False
# 2          False
# 3           True
# 4           True
# ...          ...
# 1216579    False
# 1216580    False
# 1216581    False
# 1216582    False
# 1216583    False
#
# [1216584 rows x 2 columns]

# %% [markdown]
# ## Numeric-type PII
#
# In this section, we test out PII detection on numeric-type PII (eg. phone numbers, ID numbers, IP addresses, street addresses). We compare Presidio against GCP DLP across several of these PII types (US-only for now).
#
# For evaluation purposes, we create a dataset containing:
# - the subset of all AOL queries containing numerals
# - a ~5% sample of the queries which don't contain numerals (the majority)

# %%
### Reload saved version (includes evaluation results). ###

# from sanitization_lib import EntityResult
# aol_num_eval = pd.read_pickle(NUMERIC_INSPECTED_PKL)

# %%
aol_num = aol_df.query("has_num")
# Oops, forgot to set a seed. Rerunning will create a different dataset.
aol_nonnum = aol_df.query("~has_num").sample(50000)

aol_num_eval = pd.concat([aol_num, aol_nonnum])

# %%
print(f"Num queries (numeric eval): {len(aol_num_eval):,}")
# Out:
# Num queries (numeric eval): 143,857

# %%
aol_num_eval["has_num"].value_counts()
# Out:
# True     93857
# False    50000
# Name: has_num, Length: 2, dtype: int64

# %% [markdown]
# ### Run Presidio
#
# We consider all global and US numeric-related entities.
#
# Note that Presidio doesn't have address detection, but we enable location detection instead to see how well that performs.

# %%
PRESIDIO_ENTITIES_NUM = [
    "CREDIT_CARD",
    "CRYPTO",
    "IBAN_CODE",
    "IP_ADDRESS",
    "MEDICAL_LICENSE",
    "PHONE_NUMBER",
    "MEDICAL_LICENSE",
    "US_BANK_NUMBER",
    "US_DRIVER_LICENSE",
    "US_ITIN",
    "US_PASSPORT",
    "US_SSN",
    "LOCATION",
]

presidio = sanitization_lib.PresidioScanner(entities=PRESIDIO_ENTITIES_NUM)

# %%
# %%time

# Timing is approximately linear, 10K queries per minute on local machine

aol_num_eval["presidio"] = presidio.scan_strings(aol_num_eval["query"])
# Out:
# CPU times: user 13min 59s, sys: 15.2 s, total: 14min 14s
# Wall time: 14min 51s

# %% [markdown]
# How many queries had PII detected?

# %%
aol_num_eval["presidio"].notna().sum()
# Out:
# 15616

# %% [markdown]
# ### Run DLP
#
# We enable corresponding numeric-related global and US entities.
#
# We include street address as well as location detection for comparison against Presidio.

# %%
GCP_ENTITIES_NUM = [
    "CREDIT_CARD_NUMBER",
    "IBAN_CODE",
    "IP_ADDRESS",
    "LOCATION",
    "PASSPORT",
    "PHONE_NUMBER",
    "STREET_ADDRESS",
    "SWIFT_CODE",
    "VEHICLE_IDENTIFICATION_NUMBER",
    "US_DRIVERS_LICENSE_NUMBER",
    "US_INDIVIDUAL_TAXPAYER_IDENTIFICATION_NUMBER",
    "US_PASSPORT",
    "US_SOCIAL_SECURITY_NUMBER",   
]

dlp = sanitization_lib.DLPScanner(entities=GCP_ENTITIES_NUM)

# %%
# %%time

aol_num_eval["dlp"] = dlp.scan_strings(aol_num_eval["query"])
# Out:
# CPU times: user 2.78 s, sys: 496 ms, total: 3.27 s
# Wall time: 1min 25s

# %%
aol_num_eval["dlp"] = aol_num_eval["dlp"].mask(aol_num_eval["dlp"].isna(), None)

# %% [markdown]
# How many queries had PII detected?

# %%
aol_num_eval["dlp"].notna().sum()
# Out:
# 23285

# %%
aol_num_eval[aol_num_eval["presidio"].notna() | aol_num_eval["dlp"].notna()].sample(30)
# Out:
#                                                                                                                                                                                                                                                    query  \
# 522764                                                                                                                                                                                                                             king kong cake topper
# 91847                                                                                                                                                                                                                        banks in new york 1993-1996
# 1017576                                                                                                                                                                                                                                        wilson n6
# 160782                                                                                                                                                                                                                             career fairs in miami
# 553808                                                                                                                                                                                                       list of resetrunts in the wyndmoor pa. area
# 738536                                                                                                                                                                                                                                pms.ccsd.k12.co.us
# 451120                                                                                                                                                                                            http rapidshare.de files 13753056 ned-calls preist.rar
# 1059903                                                                                                                                                                                                                www.breckenridge home oweners.com
# 709255                                                                                                                                                                                                                  paso robles junior golf march 24
# 20162                                                                                                                                                                                                                86th street cinema btwn 2nd and 3rd
# 13400                                                                                                                                                                                                                                        228 west 38
# 13827                                                                                                                                                                                                                                      2525 clark st
# 1104424                                                                                                                                                                                                                          www.hillsboro.k12.oh.us
# 176247                                                                                                                                                                                                                channel 12 news in jacksonville fl
# 13664                                                                                                                                                                                                                            24 womens mountain bike
# 236689                                                                                                                                                                                                                     current australia song charts
# 147342                                                                                                                                                                                                                         byrnes school florence sc
# 759063                                                                                                                                                                                                                            psychiatric jobs in sc
# 898790                                                                                                                                                                                                        tarrytown marriott estate planning seminar
# 104107                                                                                                                                                                                                                             bengal kittens 4 sale
# 998274                                                                                                                                                                                                                         west 93 street apartments
# 10211                                                                                                                                                                                                                        2 ct marquise cz solid gold
# 828201                                                                                                                                                                                                                         seneca youth ohio 25 beds
# 286946                                                                                                                                                                                                                           e 85 stations wisconsin
# 221494                                                                                                                                                                                                                  copper dock restaurant wisconsin
# 790203                                                                                                                                                                                                                        richard edmonds ansonia ct
# 9997                                                                                                                                                                                                                     1st dominion mortgage llc fraud
# 588312                                                                                                                                                                martinsvill virginia weather for the weekend of the 31st to the 3 of april of 2006
# 979702   virginia save governor tim kaine d capital richmond; population 7 459 827 statehood june 25 1788 - 10th state admitted nickname old dominion; motto sic semper tyrannis thus always to tyrants state bird cardinal; flower dogwood; tree dogwoo
# 734054                                                                                                                                                                                                                   pittsburgh pa penny candy store
#
#          has_num  \
# 522764     False
# 91847       True
# 1017576     True
# 160782     False
# 553808     False
# 738536      True
# 451120      True
# 1059903    False
# 709255      True
# 20162       True
# 13400       True
# 13827       True
# 1104424     True
# 176247      True
# 13664       True
# 236689     False
# 147342     False
# 759063     False
# 898790     False
# 104107      True
# 998274      True
# 10211       True
# 828201      True
# 286946      True
# 221494     False
# 790203     False
# 9997        True
# 588312      True
# 979702      True
# 734054     False
#
#                                                                         presidio  \
# 522764                                             [(LOCATION, king kong, 0.85)]
# 91847                                               [(LOCATION, new york, 0.85)]
# 1017576                                                                     None
# 160782                                                 [(LOCATION, miami, 0.85)]
# 553808                                                                      None
# 738536                                    [(LOCATION, pms.ccsd.k12.co.us, 0.85)]
# 451120   [(US_BANK_NUMBER, 13753056, 0.05), (US_DRIVER_LICENSE, 13753056, 0.01)]
# 1059903                                                                     None
# 709255                                                                      None
# 20162                                                                       None
# 13400                                                                       None
# 13827                                                                       None
# 1104424                                                                     None
# 176247                    [(LOCATION, jacksonville, 0.85), (LOCATION, fl, 0.85)]
# 13664                                        [(LOCATION, womens mountain, 0.85)]
# 236689                                                                      None
# 147342                                                                      None
# 759063                                                    [(LOCATION, sc, 0.85)]
# 898790                                                                      None
# 104107                                                [(LOCATION, bengal, 0.85)]
# 998274                                                                      None
# 10211                                                                       None
# 828201                                                  [(LOCATION, ohio, 0.85)]
# 286946                                             [(LOCATION, wisconsin, 0.85)]
# 221494                                             [(LOCATION, wisconsin, 0.85)]
# 790203                                                                      None
# 9997                                                                        None
# 588312                                                                      None
# 979702                  [(LOCATION, virginia, 0.85), (LOCATION, richmond, 0.85)]
# 734054                                            [(LOCATION, pittsburgh, 0.85)]
#
#                                                                                                                                                                        dlp
# 522764                                                                                                                                                                None
# 91847                                                                                                                                       [(LOCATION, new york, LIKELY)]
# 1017576                                                                                                                              [(STREET_ADDRESS, wilson n6, LIKELY)]
# 160782                                                                                                                                       [(LOCATION, miami, POSSIBLE)]
# 553808                                                                                                              [(LOCATION, wyndmoor, LIKELY), (LOCATION, pa, LIKELY)]
# 738536                                                                                                                  [(LOCATION, co, POSSIBLE), (LOCATION, us, LIKELY)]
# 451120                                                                                                                                                                None
# 1059903                                                                                                                               [(LOCATION, breckenridge, POSSIBLE)]
# 709255                                                                                                                                   [(LOCATION, paso robles, LIKELY)]
# 20162                                                                                                                              [(STREET_ADDRESS, 86th street, LIKELY)]
# 13400                                                                                                                                      [(LOCATION, west 38, POSSIBLE)]
# 13827                                                                                              [(LOCATION, clark st, LIKELY), (STREET_ADDRESS, 2525 clark st, LIKELY)]
# 1104424                                                                                    [(LOCATION, hillsboro, LIKELY), (LOCATION, oh, LIKELY), (LOCATION, us, LIKELY)]
# 176247                                                                                                        [(LOCATION, jacksonville, POSSIBLE), (LOCATION, fl, LIKELY)]
# 13664                                                                                                                                                                 None
# 236689                                                                                                                                   [(LOCATION, australia, POSSIBLE)]
# 147342                                                                           [(LOCATION, byrnes school, LIKELY), (LOCATION, florence, LIKELY), (LOCATION, sc, LIKELY)]
# 759063                                                                                                                                                                None
# 898790                                                                                                                                     [(LOCATION, tarrytown, LIKELY)]
# 104107                                                                                                                                                                None
# 998274                                                                              [(LOCATION, west 93 street, UNLIKELY), (STREET_ADDRESS, 93 street apartments, LIKELY)]
# 10211                                                                                                                                           [(LOCATION, 2 ct, LIKELY)]
# 828201                                                                                                                                                                None
# 286946                                                                                                                                   [(LOCATION, wisconsin, POSSIBLE)]
# 221494                                                                                                [(LOCATION, copper dock, POSSIBLE), (LOCATION, wisconsin, POSSIBLE)]
# 790203                                                                                                               [(LOCATION, ansonia, LIKELY), (LOCATION, ct, LIKELY)]
# 9997                                                                                                                         [(LOCATION, dominion mortgage llc, POSSIBLE)]
# 588312                                                                                                     [(LOCATION, martinsvill, LIKELY), (LOCATION, virginia, LIKELY)]
# 979702   [(LOCATION, virginia, LIKELY), (LOCATION, richmond, LIKELY), (PHONE_NUMBER, 7 459 827, UNLIKELY), (LOCATION, old dominion, LIKELY), (LOCATION, dogwoo, POSSIBLE)]
# 734054                                                                                                            [(LOCATION, pittsburgh, LIKELY), (LOCATION, pa, LIKELY)]
#
# [30 rows x 4 columns]

# %% [markdown]
# Persist inspection results.

# %%
aol_num_eval.to_pickle(NUMERIC_INSPECTED_PKL)

# %% [markdown]
# ### Locations
#
# How well does the location detection work?
#
# - By looking at some examples, we find it's not a great indicator of PII. It flags general locations, eg "cities in texas" and misses some actual addresses.
#
# We will not use location detection further.

# %%
(
    aol_num_eval
    .assign(
        has_location=aol_num_eval["presidio"].map(lambda x: x is not None and "LOCATION" in [y.type for y in x]),
        has_address=aol_num_eval["dlp"].map(lambda x: x is not None and "STREET_ADDRESS" in [y.type for y in x]),
    )
    .query("has_location")
#     .query("has_address")
    .sample(30)
)
# Out:
#                                                     query  has_num  \
# 174692                                        chad africa    False
# 850346                                      smithville pa    False
# 247608                            days inn in panama city    False
# 493734                             jason gerhard and ohio    False
# 537955          las vegas twenty dollar double eagle 1907     True
# 427011                          homes for rent in orlando    False
# 151695        california women steals police suv 3 3 2006     True
# 1012049   who was the leader of canada during world war 2     True
# 921315            theatre in tucson arizona in april 2006     True
# 562111                   los angeles museum of modern art    False
# 653608       nebraska state science olympiad 2006 results     True
# 742890                          poor credit mortgage utah    False
# 425277               home for seal on 52 wiliamsporg ohio     True
# 343120                             fort myers florida 99x     True
# 965092      used cadilac eldorado engine 1997 in michigan     True
# 891907                 sweetwater apartments in dade city    False
# 980462                       visinet 20inc 20and 20 omaha     True
# 924219                third degree folney in pennsylvania    False
# 932538                       toledo ohio public utilities    False
# 176258                 channel 13 news and brevard county     True
# 550030                     lighthouse pacifica california    False
# 7605     1964 washington high school pictures souix falls     True
# 5613                             131 main huntersville nc     True
# 979310             virginia amended tax returns 2003 2004     True
# 165661                             casimir united kingdom    False
# 17195                                          5 towns li     True
# 510098                            june 2006 f&i events ma     True
# 684200                               ohio departmentation    False
# 957800                united 20states 20 postal 20service     True
# 623905                         monterey peninsula college    False
#
#                                                               presidio  \
# 174692                                 [(LOCATION, chad africa, 0.85)]
# 850346            [(LOCATION, smithville, 0.85), (LOCATION, pa, 0.85)]
# 247608                                 [(LOCATION, panama city, 0.85)]
# 493734                                        [(LOCATION, ohio, 0.85)]
# 537955                                   [(LOCATION, las vegas, 0.85)]
# 427011                                     [(LOCATION, orlando, 0.85)]
# 151695   [(LOCATION, california, 0.85), (PHONE_NUMBER, 3 3 2006, 0.4)]
# 1012049                                     [(LOCATION, canada, 0.85)]
# 921315                              [(LOCATION, tucson arizona, 0.85)]
# 562111                                 [(LOCATION, los angeles, 0.85)]
# 653608                                    [(LOCATION, nebraska, 0.85)]
# 742890                                        [(LOCATION, utah, 0.85)]
# 425277                                        [(LOCATION, ohio, 0.85)]
# 343120                                     [(LOCATION, florida, 0.85)]
# 965092                                    [(LOCATION, michigan, 0.85)]
# 891907                                   [(LOCATION, dade city, 0.85)]
# 980462                                       [(LOCATION, omaha, 0.85)]
# 924219                                [(LOCATION, pennsylvania, 0.85)]
# 932538              [(LOCATION, toledo, 0.85), (LOCATION, ohio, 0.85)]
# 176258                              [(LOCATION, brevard county, 0.85)]
# 550030                                  [(LOCATION, california, 0.85)]
# 7605           [(LOCATION, washington, 0.85), (LOCATION, souix, 0.85)]
# 5613            [(LOCATION, huntersville, 0.85), (LOCATION, nc, 0.85)]
# 979310                                    [(LOCATION, virginia, 0.85)]
# 165661                      [(LOCATION, casimir united kingdom, 0.85)]
# 17195                                           [(LOCATION, li, 0.85)]
# 510098                                          [(LOCATION, ma, 0.85)]
# 684200                                        [(LOCATION, ohio, 0.85)]
# 957800                                      [(LOCATION, united, 0.85)]
# 623905                          [(LOCATION, monterey peninsula, 0.85)]
#
#                                                                                                                                                   dlp  \
# 174692                                                                                                                   [(LOCATION, chad, POSSIBLE)]
# 850346                                                                                     [(LOCATION, smithville, POSSIBLE), (LOCATION, pa, LIKELY)]
# 247608                                                                                                              [(LOCATION, panama city, LIKELY)]
# 493734                                                                                                                     [(LOCATION, ohio, LIKELY)]
# 537955                                                                                                                [(LOCATION, las vegas, LIKELY)]
# 427011                                                                                                                  [(LOCATION, orlando, LIKELY)]
# 151695                                                                                                               [(LOCATION, california, LIKELY)]
# 1012049                                                                                                                [(LOCATION, canada, POSSIBLE)]
# 921315                                                                                      [(LOCATION, tucson, LIKELY), (LOCATION, arizona, LIKELY)]
# 562111                                                                  [(LOCATION, los angeles, LIKELY), (LOCATION, museum of modern art, POSSIBLE)]
# 653608                                                                                                                                           None
# 742890                                                                                                                   [(LOCATION, utah, POSSIBLE)]
# 425277                                                                                                                     [(LOCATION, ohio, LIKELY)]
# 343120                                    [(LOCATION, fort myers, LIKELY), (STREET_ADDRESS, fort myers florida, LIKELY), (LOCATION, florida, LIKELY)]
# 965092                                                                                                               [(LOCATION, michigan, POSSIBLE)]
# 891907                                                                              [(LOCATION, sweetwater, LIKELY), (LOCATION, dade city, POSSIBLE)]
# 980462                                                                                                                  [(LOCATION, omaha, POSSIBLE)]
# 924219                                                                                                             [(LOCATION, pennsylvania, LIKELY)]
# 932538                                                                                         [(LOCATION, toledo, LIKELY), (LOCATION, ohio, LIKELY)]
# 176258                                                                                                                                           None
# 550030                                                                                                      [(LOCATION, pacifica california, LIKELY)]
# 7605                                                                    [(LOCATION, washington high school, LIKELY), (LOCATION, souix falls, LIKELY)]
# 5613     [(LOCATION, 131 main, LIKELY), (LOCATION, huntersville, LIKELY), (LOCATION, nc, LIKELY), (STREET_ADDRESS, 131 main huntersville nc, LIKELY)]
# 979310                                                                            [(LOCATION, virginia, LIKELY), (PHONE_NUMBER, 2003 2004, UNLIKELY)]
# 165661                                                                                                           [(LOCATION, united kingdom, LIKELY)]
# 17195                                                                                                                                            None
# 510098                                                                                                                                           None
# 684200                                                                                                                   [(LOCATION, ohio, POSSIBLE)]
# 957800                                                                                                                                           None
# 623905                                                                                               [(LOCATION, monterey peninsula college, LIKELY)]
#
#          has_location  has_address
# 174692           True        False
# 850346           True        False
# 247608           True        False
# 493734           True        False
# 537955           True        False
# 427011           True        False
# 151695           True        False
# 1012049          True        False
# 921315           True        False
# 562111           True        False
# 653608           True        False
# 742890           True        False
# 425277           True        False
# 343120           True         True
# 965092           True        False
# 891907           True        False
# 980462           True        False
# 924219           True        False
# 932538           True        False
# 176258           True        False
# 550030           True        False
# 7605             True        False
# 5613             True         True
# 979310           True        False
# 165661           True        False
# 17195            True        False
# 510098           True        False
# 684200           True        False
# 957800           True        False
# 623905           True        False
#
# [30 rows x 6 columns]

# %% [markdown]
# Drop location from detection results for both Presidio and GCP.

# %%
def drop_locations(r):
    if r is None:
        return None
    r = [x for x in r if x.type != "LOCATION"]
    if not r:
        return None
    return r

aol_num_eval["presidio"] = aol_num_eval["presidio"].map(drop_locations)
aol_num_eval["dlp"] = aol_num_eval["dlp"].map(drop_locations)

# %% [markdown]
# ### Detection results comparison
#
# How does detection match up for the two libraries?

# %%
def pivot_detection_counts(counts_df, index="presidio", columns="dlp"):
    return (
        counts_df
        .pivot_table(
            index=index,
            columns=columns,
            fill_value=0,
            aggfunc=sum,
            margins=True,
            margins_name="total"
        )
        .style.format("{:,}")
    )

# %%
pivot_detection_counts(
    aol_num_eval
    .groupby([
        aol_num_eval["presidio"].notna().astype(str),
        aol_num_eval["dlp"].notna().astype(str)
    ])
    .size()
    .reset_index(name="count")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a088a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a088a_level0_col0" class="col_heading level0 col0" colspan="3">count</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >dlp</th>
#       <th id="T_a088a_level1_col0" class="col_heading level1 col0" >False</th>
#       <th id="T_a088a_level1_col1" class="col_heading level1 col1" >True</th>
#       <th id="T_a088a_level1_col2" class="col_heading level1 col2" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >presidio</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a088a_level0_row0" class="row_heading level0 row0" >False</th>
#       <td id="T_a088a_row0_col0" class="data row0 col0" >139,226</td>
#       <td id="T_a088a_row0_col1" class="data row0 col1" >2,137</td>
#       <td id="T_a088a_row0_col2" class="data row0 col2" >141,363</td>
#     </tr>
#     <tr>
#       <th id="T_a088a_level0_row1" class="row_heading level0 row1" >True</th>
#       <td id="T_a088a_row1_col0" class="data row1 col0" >1,485</td>
#       <td id="T_a088a_row1_col1" class="data row1 col1" >1,009</td>
#       <td id="T_a088a_row1_col2" class="data row1 col2" >2,494</td>
#     </tr>
#     <tr>
#       <th id="T_a088a_level0_row2" class="row_heading level0 row2" >total</th>
#       <td id="T_a088a_row2_col0" class="data row2 col0" >140,711</td>
#       <td id="T_a088a_row2_col1" class="data row2 col1" >3,146</td>
#       <td id="T_a088a_row2_col2" class="data row2 col2" >143,857</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Presidio doesn't include addresses. How do these results change if we exclude address detection?

# %%
def detected(r, exclude=[]):
    if not r:
        return "False"
    return str(bool(len([x for x in r if x.type not in exclude])))

pivot_detection_counts(
    aol_num_eval
    .groupby([
        aol_num_eval["presidio"].notna().astype(str),
        aol_num_eval["dlp"].map(lambda x: detected(x, exclude=["STREET_ADDRESS"])),
    ])
    .size()
    .reset_index(name="count")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_699c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_699c1_level0_col0" class="col_heading level0 col0" colspan="3">count</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >dlp</th>
#       <th id="T_699c1_level1_col0" class="col_heading level1 col0" >False</th>
#       <th id="T_699c1_level1_col1" class="col_heading level1 col1" >True</th>
#       <th id="T_699c1_level1_col2" class="col_heading level1 col2" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >presidio</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_699c1_level0_row0" class="row_heading level0 row0" >False</th>
#       <td id="T_699c1_row0_col0" class="data row0 col0" >140,871</td>
#       <td id="T_699c1_row0_col1" class="data row0 col1" >492</td>
#       <td id="T_699c1_row0_col2" class="data row0 col2" >141,363</td>
#     </tr>
#     <tr>
#       <th id="T_699c1_level0_row1" class="row_heading level0 row1" >True</th>
#       <td id="T_699c1_row1_col0" class="data row1 col0" >1,516</td>
#       <td id="T_699c1_row1_col1" class="data row1 col1" >978</td>
#       <td id="T_699c1_row1_col2" class="data row1 col2" >2,494</td>
#     </tr>
#     <tr>
#       <th id="T_699c1_level0_row2" class="row_heading level0 row2" >total</th>
#       <td id="T_699c1_row2_col0" class="data row2 col0" >142,387</td>
#       <td id="T_699c1_row2_col1" class="data row2 col1" >1,470</td>
#       <td id="T_699c1_row2_col2" class="data row2 col2" >143,857</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# What do the scores look like for detected entities?

# %%
def show_score_distributions(result_series):
    flat_results = result_series.explode().dropna()
    flat_results = pd.concat(
        [
            flat_results.map(lambda r: r.type).rename("entity"),
            flat_results.map(lambda r: r.score).rename("score"),
        ],
        axis="columns"
    )
    score_cts = flat_results.value_counts().sort_index().to_frame(name="count")
        
    
    display(
        score_cts
        .assign(prop=lambda x: x["count"].groupby("entity").transform(lambda s: s / s.sum()))
        .style.format({"prop_within_entity": "{:.1%}"})
    )

    display(
        score_cts
        .groupby("score")
        .agg({"count": "sum"})
        .assign(prop=lambda x: x["count"] / x["count"].sum())
        .style.format({"prop": "{:.1%}"})
    )

# %% [markdown]
# Presidio:

# %%
show_score_distributions(aol_num_eval["presidio"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_86317">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86317_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_86317_level0_col1" class="col_heading level0 col1" >prop</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >entity</th>
#       <th class="index_name level1" >score</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86317_level0_row0" class="row_heading level0 row0" >CREDIT_CARD</th>
#       <th id="T_86317_level1_row0" class="row_heading level1 row0" >1.000000</th>
#       <td id="T_86317_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_86317_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row1" class="row_heading level0 row1" rowspan="2">IP_ADDRESS</th>
#       <th id="T_86317_level1_row1" class="row_heading level1 row1" >0.600000</th>
#       <td id="T_86317_row1_col0" class="data row1 col0" >408</td>
#       <td id="T_86317_row1_col1" class="data row1 col1" >0.978417</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level1_row2" class="row_heading level1 row2" >0.950000</th>
#       <td id="T_86317_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_86317_row2_col1" class="data row2 col1" >0.021583</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row3" class="row_heading level0 row3" >LOCATION</th>
#       <th id="T_86317_level1_row3" class="row_heading level1 row3" >0.850000</th>
#       <td id="T_86317_row3_col0" class="data row3 col0" >15206</td>
#       <td id="T_86317_row3_col1" class="data row3 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row4" class="row_heading level0 row4" >MEDICAL_LICENSE</th>
#       <th id="T_86317_level1_row4" class="row_heading level1 row4" >1.000000</th>
#       <td id="T_86317_row4_col0" class="data row4 col0" >48</td>
#       <td id="T_86317_row4_col1" class="data row4 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row5" class="row_heading level0 row5" rowspan="2">PHONE_NUMBER</th>
#       <th id="T_86317_level1_row5" class="row_heading level1 row5" >0.400000</th>
#       <td id="T_86317_row5_col0" class="data row5 col0" >1002</td>
#       <td id="T_86317_row5_col1" class="data row5 col1" >0.974708</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level1_row6" class="row_heading level1 row6" >0.750000</th>
#       <td id="T_86317_row6_col0" class="data row6 col0" >26</td>
#       <td id="T_86317_row6_col1" class="data row6 col1" >0.025292</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row7" class="row_heading level0 row7" rowspan="2">US_BANK_NUMBER</th>
#       <th id="T_86317_level1_row7" class="row_heading level1 row7" >0.050000</th>
#       <td id="T_86317_row7_col0" class="data row7 col0" >838</td>
#       <td id="T_86317_row7_col1" class="data row7 col1" >0.989374</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level1_row8" class="row_heading level1 row8" >0.400000</th>
#       <td id="T_86317_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_86317_row8_col1" class="data row8 col1" >0.010626</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row9" class="row_heading level0 row9" rowspan="2">US_DRIVER_LICENSE</th>
#       <th id="T_86317_level1_row9" class="row_heading level1 row9" >0.010000</th>
#       <td id="T_86317_row9_col0" class="data row9 col0" >1655</td>
#       <td id="T_86317_row9_col1" class="data row9 col1" >0.988650</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level1_row10" class="row_heading level1 row10" >0.400000</th>
#       <td id="T_86317_row10_col0" class="data row10 col0" >19</td>
#       <td id="T_86317_row10_col1" class="data row10 col1" >0.011350</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row11" class="row_heading level0 row11" >US_ITIN</th>
#       <th id="T_86317_level1_row11" class="row_heading level1 row11" >0.300000</th>
#       <td id="T_86317_row11_col0" class="data row11 col0" >3</td>
#       <td id="T_86317_row11_col1" class="data row11 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row12" class="row_heading level0 row12" rowspan="2">US_PASSPORT</th>
#       <th id="T_86317_level1_row12" class="row_heading level1 row12" >0.050000</th>
#       <td id="T_86317_row12_col0" class="data row12 col0" >135</td>
#       <td id="T_86317_row12_col1" class="data row12 col1" >0.931034</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level1_row13" class="row_heading level1 row13" >0.400000</th>
#       <td id="T_86317_row13_col0" class="data row13 col0" >10</td>
#       <td id="T_86317_row13_col1" class="data row13 col1" >0.068966</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level0_row14" class="row_heading level0 row14" rowspan="2">US_SSN</th>
#       <th id="T_86317_level1_row14" class="row_heading level1 row14" >0.050000</th>
#       <td id="T_86317_row14_col0" class="data row14 col0" >154</td>
#       <td id="T_86317_row14_col1" class="data row14 col1" >0.968553</td>
#     </tr>
#     <tr>
#       <th id="T_86317_level1_row15" class="row_heading level1 row15" >0.500000</th>
#       <td id="T_86317_row15_col0" class="data row15 col0" >5</td>
#       <td id="T_86317_row15_col1" class="data row15 col1" >0.031447</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_26c18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26c18_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_26c18_level0_col1" class="col_heading level0 col1" >prop</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >score</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26c18_level0_row0" class="row_heading level0 row0" >0.010000</th>
#       <td id="T_26c18_row0_col0" class="data row0 col0" >1655</td>
#       <td id="T_26c18_row0_col1" class="data row0 col1" >8.5%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row1" class="row_heading level0 row1" >0.050000</th>
#       <td id="T_26c18_row1_col0" class="data row1 col0" >1127</td>
#       <td id="T_26c18_row1_col1" class="data row1 col1" >5.8%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row2" class="row_heading level0 row2" >0.300000</th>
#       <td id="T_26c18_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_26c18_row2_col1" class="data row2 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row3" class="row_heading level0 row3" >0.400000</th>
#       <td id="T_26c18_row3_col0" class="data row3 col0" >1040</td>
#       <td id="T_26c18_row3_col1" class="data row3 col1" >5.3%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row4" class="row_heading level0 row4" >0.500000</th>
#       <td id="T_26c18_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_26c18_row4_col1" class="data row4 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row5" class="row_heading level0 row5" >0.600000</th>
#       <td id="T_26c18_row5_col0" class="data row5 col0" >408</td>
#       <td id="T_26c18_row5_col1" class="data row5 col1" >2.1%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row6" class="row_heading level0 row6" >0.750000</th>
#       <td id="T_26c18_row6_col0" class="data row6 col0" >26</td>
#       <td id="T_26c18_row6_col1" class="data row6 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row7" class="row_heading level0 row7" >0.850000</th>
#       <td id="T_26c18_row7_col0" class="data row7 col0" >15206</td>
#       <td id="T_26c18_row7_col1" class="data row7 col1" >77.8%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row8" class="row_heading level0 row8" >0.950000</th>
#       <td id="T_26c18_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_26c18_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_26c18_level0_row9" class="row_heading level0 row9" >1.000000</th>
#       <td id="T_26c18_row9_col0" class="data row9 col0" >60</td>
#       <td id="T_26c18_row9_col1" class="data row9 col1" >0.3%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# DLP:

# %%
show_score_distributions(aol_num_eval["dlp"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_03b82">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03b82_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_03b82_level0_col1" class="col_heading level0 col1" >prop</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >entity</th>
#       <th class="index_name level1" >score</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03b82_level0_row0" class="row_heading level0 row0" rowspan="3">CREDIT_CARD_NUMBER</th>
#       <th id="T_03b82_level1_row0" class="row_heading level1 row0" >POSSIBLE</th>
#       <td id="T_03b82_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_03b82_row0_col1" class="data row0 col1" >0.437500</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row1" class="row_heading level1 row1" >UNLIKELY</th>
#       <td id="T_03b82_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_03b82_row1_col1" class="data row1 col1" >0.437500</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row2" class="row_heading level1 row2" >VERY_UNLIKELY</th>
#       <td id="T_03b82_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_03b82_row2_col1" class="data row2 col1" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level0_row3" class="row_heading level0 row3" rowspan="3">IP_ADDRESS</th>
#       <th id="T_03b82_level1_row3" class="row_heading level1 row3" >LIKELY</th>
#       <td id="T_03b82_row3_col0" class="data row3 col0" >67</td>
#       <td id="T_03b82_row3_col1" class="data row3 col1" >0.208075</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row4" class="row_heading level1 row4" >POSSIBLE</th>
#       <td id="T_03b82_row4_col0" class="data row4 col0" >254</td>
#       <td id="T_03b82_row4_col1" class="data row4 col1" >0.788820</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row5" class="row_heading level1 row5" >UNLIKELY</th>
#       <td id="T_03b82_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_03b82_row5_col1" class="data row5 col1" >0.003106</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level0_row6" class="row_heading level0 row6" >PASSPORT</th>
#       <th id="T_03b82_level1_row6" class="row_heading level1 row6" >UNLIKELY</th>
#       <td id="T_03b82_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_03b82_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level0_row7" class="row_heading level0 row7" rowspan="5">PHONE_NUMBER</th>
#       <th id="T_03b82_level1_row7" class="row_heading level1 row7" >LIKELY</th>
#       <td id="T_03b82_row7_col0" class="data row7 col0" >10</td>
#       <td id="T_03b82_row7_col1" class="data row7 col1" >0.009174</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row8" class="row_heading level1 row8" >POSSIBLE</th>
#       <td id="T_03b82_row8_col0" class="data row8 col0" >416</td>
#       <td id="T_03b82_row8_col1" class="data row8 col1" >0.381651</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row9" class="row_heading level1 row9" >UNLIKELY</th>
#       <td id="T_03b82_row9_col0" class="data row9 col0" >622</td>
#       <td id="T_03b82_row9_col1" class="data row9 col1" >0.570642</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row10" class="row_heading level1 row10" >VERY_LIKELY</th>
#       <td id="T_03b82_row10_col0" class="data row10 col0" >20</td>
#       <td id="T_03b82_row10_col1" class="data row10 col1" >0.018349</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row11" class="row_heading level1 row11" >VERY_UNLIKELY</th>
#       <td id="T_03b82_row11_col0" class="data row11 col0" >22</td>
#       <td id="T_03b82_row11_col1" class="data row11 col1" >0.020183</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level0_row12" class="row_heading level0 row12" >STREET_ADDRESS</th>
#       <th id="T_03b82_level1_row12" class="row_heading level1 row12" >LIKELY</th>
#       <td id="T_03b82_row12_col0" class="data row12 col0" >1751</td>
#       <td id="T_03b82_row12_col1" class="data row12 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level0_row13" class="row_heading level0 row13" >US_DRIVERS_LICENSE_NUMBER</th>
#       <th id="T_03b82_level1_row13" class="row_heading level1 row13" >UNLIKELY</th>
#       <td id="T_03b82_row13_col0" class="data row13 col0" >7</td>
#       <td id="T_03b82_row13_col1" class="data row13 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level0_row14" class="row_heading level0 row14" >US_INDIVIDUAL_TAXPAYER_IDENTIFICATION_NUMBER</th>
#       <th id="T_03b82_level1_row14" class="row_heading level1 row14" >UNLIKELY</th>
#       <td id="T_03b82_row14_col0" class="data row14 col0" >4</td>
#       <td id="T_03b82_row14_col1" class="data row14 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level0_row15" class="row_heading level0 row15" rowspan="3">US_SOCIAL_SECURITY_NUMBER</th>
#       <th id="T_03b82_level1_row15" class="row_heading level1 row15" >LIKELY</th>
#       <td id="T_03b82_row15_col0" class="data row15 col0" >1</td>
#       <td id="T_03b82_row15_col1" class="data row15 col1" >0.009709</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row16" class="row_heading level1 row16" >POSSIBLE</th>
#       <td id="T_03b82_row16_col0" class="data row16 col0" >5</td>
#       <td id="T_03b82_row16_col1" class="data row16 col1" >0.048544</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row17" class="row_heading level1 row17" >UNLIKELY</th>
#       <td id="T_03b82_row17_col0" class="data row17 col0" >97</td>
#       <td id="T_03b82_row17_col1" class="data row17 col1" >0.941748</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level0_row18" class="row_heading level0 row18" rowspan="2">VEHICLE_IDENTIFICATION_NUMBER</th>
#       <th id="T_03b82_level1_row18" class="row_heading level1 row18" >POSSIBLE</th>
#       <td id="T_03b82_row18_col0" class="data row18 col0" >3</td>
#       <td id="T_03b82_row18_col1" class="data row18 col1" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_03b82_level1_row19" class="row_heading level1 row19" >UNLIKELY</th>
#       <td id="T_03b82_row19_col0" class="data row19 col0" >9</td>
#       <td id="T_03b82_row19_col1" class="data row19 col1" >0.750000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7d96c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d96c_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_7d96c_level0_col1" class="col_heading level0 col1" >prop</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >score</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d96c_level0_row0" class="row_heading level0 row0" >LIKELY</th>
#       <td id="T_7d96c_row0_col0" class="data row0 col0" >1829</td>
#       <td id="T_7d96c_row0_col1" class="data row0 col1" >55.3%</td>
#     </tr>
#     <tr>
#       <th id="T_7d96c_level0_row1" class="row_heading level0 row1" >POSSIBLE</th>
#       <td id="T_7d96c_row1_col0" class="data row1 col0" >685</td>
#       <td id="T_7d96c_row1_col1" class="data row1 col1" >20.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7d96c_level0_row2" class="row_heading level0 row2" >UNLIKELY</th>
#       <td id="T_7d96c_row2_col0" class="data row2 col0" >748</td>
#       <td id="T_7d96c_row2_col1" class="data row2 col1" >22.6%</td>
#     </tr>
#     <tr>
#       <th id="T_7d96c_level0_row3" class="row_heading level0 row3" >VERY_LIKELY</th>
#       <td id="T_7d96c_row3_col0" class="data row3 col0" >20</td>
#       <td id="T_7d96c_row3_col1" class="data row3 col1" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_7d96c_level0_row4" class="row_heading level0 row4" >VERY_UNLIKELY</th>
#       <td id="T_7d96c_row4_col0" class="data row4 col0" >24</td>
#       <td id="T_7d96c_row4_col1" class="data row4 col1" >0.7%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Manual labeling
#
# __Note: this section documents the manual labeling process.
# It has already been performed and the results can be loaded from file.__
#
# In order to evaluate correctness, we manually label a small subset of queries as PII/non-PII.
#
# To ensure adequate coverage of the different PII categories, the subset is sampled with stratification over the DLP score levels as follows:
#
# - 500 of LIKELY/VERY_LIKELY queries containing numerics
# - 500 of POSSIBLE queries containing numerics
# - 500 of UNLIKELY/VERY_UNLIKELY queries containing numerics
# - 500 of non-flagged queries containing numerics
# - 500 of queries not containing numerics (regardless of whether they were flagged)
#
# When a query has multiple PII, the highest detected level is used.
#
# Each query is labeled as one of
# - is PII
# - maybe PII
# - not PII
#
# regardless of PII type.
# For the purposes of this analysis, only numeric-related PII types are considered. People's names are _not_ labeled as PII.

# %%
### Reload saved version (includes labels). ###

# num_aol_labeled = pd.read_pickle(NUMERIC_LABELED_PKL)

# %%
def get_dlp_max(r):
    if not isinstance(r, list):
        return None
    scores = [x.score for x in r]
    if "LIKELY" in scores or "VERY_LIKELY" in scores:
        return "high"
    if "POSSIBLE" in scores:
        return "med"
    return "low"
        

aol_num_eval["dlp_max_score"] = aol_num_eval["dlp"].map(get_dlp_max)

# %%
aol_num_eval["dlp_max_score"].value_counts(dropna=False)
# Out:
# None    140711
# high      1814
# med        673
# low        659
# Name: dlp_max_score, Length: 4, dtype: int64

# %%
num_aol_labeling = pd.concat([
    aol_num_eval.query("has_num & (dlp_max_score == 'high')").sample(500),
    aol_num_eval.query("has_num & (dlp_max_score == 'med')").sample(500),
    aol_num_eval.query("has_num & (dlp_max_score == 'low')").sample(500),
    aol_num_eval.query("has_num & dlp.isna()").sample(500),
    aol_num_eval.query("~has_num").sample(500),
])
num_aol_labeling = num_aol_labeling.sort_values("query")
num_aol_labeling["is_pii"] = None

# %%
num_aol_labeling[["has_num", "dlp_max_score"]].value_counts(dropna=False)
# Out:
# has_num  dlp_max_score
# False    NaN              500
# True     high             500
#          low              500
#          med              500
#          NaN              500
# Length: 5, dtype: int64

# %%
TMP_LABELING_CSV = "./aol_num_queries.csv"

# %%
num_aol_labeling.to_csv(TMP_LABELING_CSV, columns=["query", "is_pii"])

# %% [markdown]
# Queries are labelled manually using `t`(true - is PII)/`m` (maybe)/`<blank>` (false - not PII).
#
#
# - CSV file is opened using the [Spreadsheet Editor](https://github.com/jupyterlab-contrib/jupyterlab-spreadsheet-editor) extension
# - The labels are entered in the `is_pii` column.
# - The CSV is saved in the editor and reloaded here.

# %%
num_aol_labeled = pd.read_csv(TMP_LABELING_CSV, index_col=0)

# %%
num_aol_labeled
# Out:
#                                                                                                                                                                                                                                                     query  \
# 335                                                                                                                                                                          ----- forwarded by jackie sloan res clubcorp us on 02 27 2006 03 28 pm -----
# 350      -----------------forwarded message subj fwd some thoughts 4 u date 4 12 2006 1 42 12 p.m. central daylight time from gdvtek to gdvtek -----------------forwarded message subj fwd some thoughts 4 u date 4 12 2006 1 41 30 p.m. central daylight
# 547                                                                                                                                                                                                                            ...............0000.00000.
# 679                                                                                                                                                                                                                                                    .7
# 680                                                                                                                                                                                                                                        .71.244.90.56.
# ...                                                                                                                                                                                                                                                   ...
# 1214022                                                                                                                                                                                                                           zach winslow 12 31 2005
# 1214026                                                                                                                                                                                                                    zach winslow r.i.p. 12 31 2005
# 1215292                                                                                                                                                                                                         zip code 619 o'hare street edinburg texas
# 1215479                                                                                                                                                                                                                              zip codes in georgia
# 1215612                                                                                                                                                                                                                                 zippo 4001-000271
#
#         is_pii
# 335        NaN
# 350        NaN
# 547        NaN
# 679        NaN
# 680          t
# ...        ...
# 1214022    NaN
# 1214026    NaN
# 1215292      t
# 1215479    NaN
# 1215612    NaN
#
# [2500 rows x 2 columns]

# %%
assert num_aol_labeled["query"].isna().sum() == 0
assert len(num_aol_labeled) == len(num_aol_labeling)

# %% [markdown]
# Fill out full labels for PII.

# %%
PII_LABELS = {
    "t": "yes",
    "m": "maybe",
    np.nan: "no",
}

# %%
num_aol_labeled["is_pii"] = num_aol_labeled["is_pii"].map(PII_LABELS)

# %%
assert num_aol_labeled["is_pii"].isna().sum() == 0

# %%
num_aol_labeled
# Out:
#                                                                                                                                                                                                                                                     query  \
# 335                                                                                                                                                                          ----- forwarded by jackie sloan res clubcorp us on 02 27 2006 03 28 pm -----
# 350      -----------------forwarded message subj fwd some thoughts 4 u date 4 12 2006 1 42 12 p.m. central daylight time from gdvtek to gdvtek -----------------forwarded message subj fwd some thoughts 4 u date 4 12 2006 1 41 30 p.m. central daylight
# 547                                                                                                                                                                                                                            ...............0000.00000.
# 679                                                                                                                                                                                                                                                    .7
# 680                                                                                                                                                                                                                                        .71.244.90.56.
# ...                                                                                                                                                                                                                                                   ...
# 188720                                                                                                                                                                                                                                   chinese diet tea
# 1023870                                                                                                                                                                                                                              wood filing cabinets
# 395072                                                                                                                                                                                                                                               gria
# 164596                                                                                                                                                                                                                                    cartoon.network
# 920088                                                                                                                                                                                                                                           the unit
#
#         is_pii
# 335         no
# 350         no
# 547         no
# 679         no
# 680        yes
# ...        ...
# 188720      no
# 1023870     no
# 395072      no
# 164596      no
# 920088      no
#
# [2500 rows x 2 columns]

# %% [markdown]
# Pull in the inspection results from the full DF.

# %%
num_aol_labeled = pd.merge(
    aol_num_eval, num_aol_labeled, left_index=True, right_index=True, suffixes=(None, "_")
)

# %%
assert len(num_aol_labeled.query("query != query_")) == 0

# %%
num_aol_labeled = num_aol_labeled.drop(columns="query_")

# %%
num_aol_labeled.head()
# Out:
#                                                                                                                                                                                                                                                 query  \
# 335                                                                                                                                                                      ----- forwarded by jackie sloan res clubcorp us on 02 27 2006 03 28 pm -----
# 350  -----------------forwarded message subj fwd some thoughts 4 u date 4 12 2006 1 42 12 p.m. central daylight time from gdvtek to gdvtek -----------------forwarded message subj fwd some thoughts 4 u date 4 12 2006 1 41 30 p.m. central daylight
# 547                                                                                                                                                                                                                        ...............0000.00000.
# 679                                                                                                                                                                                                                                                .7
# 680                                                                                                                                                                                                                                    .71.244.90.56.
#
#      has_num                                 presidio  \
# 335     True  [(PHONE_NUMBER, 02 27 2006 03 28, 0.4)]
# 350     True                                     None
# 547     True                                     None
# 679     True                                     None
# 680     True        [(IP_ADDRESS, 71.244.90.56, 0.6)]
#
#                                                                                         dlp  \
# 335                                            [(PHONE_NUMBER, 02 27 2006 03 28, UNLIKELY)]
# 350  [(PHONE_NUMBER, 12 2006 1 42 12, UNLIKELY), (PHONE_NUMBER, 12 2006 1 41 30, UNLIKELY)]
# 547                                                  [(PHONE_NUMBER, 0000.00000, UNLIKELY)]
# 679                                                                                    None
# 680                                                  [(IP_ADDRESS, 71.244.90.56, POSSIBLE)]
#
#     dlp_max_score is_pii
# 335           low     no
# 350           low     no
# 547           low     no
# 679          None     no
# 680           med    yes
#
# [5 rows x 6 columns]

# %% [markdown]
# Persist labeling results.

# %%
num_aol_labeled.to_pickle(NUMERIC_LABELED_PKL)

# %% [markdown]
# ### Detection results accuracy
#
# How do the two inspection libraries compare?

# %%
num_aol_labeled["is_pii"] = pd.Categorical(
    num_aol_labeled["is_pii"], categories=["yes", "maybe", "no"], ordered=True
)

def lab_gp(r):
    if r["dlp_max_score"]:
        return f"num_flagged_{r['dlp_max_score']}"
    if r["has_num"]:
        return "num_unflagged"
    return "nonnum"

num_aol_labeled["grouping"] = pd.Categorical(
    num_aol_labeled.apply(lab_gp, axis="columns"),
    categories=["num_flagged_high", "num_flagged_med", "num_flagged_low", "num_unflagged", "nonnum"],
    ordered=True
)

# %%
dlp_presidio_comp = (
    num_aol_labeled
    .groupby(["grouping", "is_pii"], observed=True)
    .agg(
        dlp_flagged=pd.NamedAgg("dlp", lambda s: s.notna().sum()),
        dlp_not_flagged=pd.NamedAgg("dlp", lambda s: s.isna().sum()),
        presidio_flagged=pd.NamedAgg("presidio", lambda s: s.notna().sum()), 
        presidio_not_flagged=pd.NamedAgg("presidio", lambda s: s.isna().sum()), 
    )
)

# %%
dlp_presidio_comp
# Out:
#                          dlp_flagged  dlp_not_flagged  presidio_flagged  \
# grouping         is_pii
# num_flagged_high yes             276                0                40
#                  maybe            13                0                 1
#                  no              211                0                 4
# num_flagged_med  yes             466                0               464
#                  maybe            12                0                 7
#                  no               19                0                11
# num_flagged_low  yes              24                0                20
#                  maybe           125                0                64
#                  no              354                0                88
# num_unflagged    maybe             0               12                 4
#                  no                0              488                 3
# nonnum           maybe             0                3                 0
#                  no                0              497                 0
#
#                          presidio_not_flagged
# grouping         is_pii
# num_flagged_high yes                      236
#                  maybe                     12
#                  no                       207
# num_flagged_med  yes                        2
#                  maybe                      5
#                  no                         8
# num_flagged_low  yes                        4
#                  maybe                     61
#                  no                       266
# num_unflagged    maybe                      8
#                  no                       485
# nonnum           maybe                      3
#                  no                       497
#
# [13 rows x 4 columns]

# %%
(
    num_aol_labeled["is_pii"]
    .value_counts()
    .sort_index()
    .to_frame()
    .assign(prop=lambda x: x["is_pii"] / x["is_pii"].sum())
    .style.format({"prop": "{:.1%}"})
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_faeb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faeb6_level0_col0" class="col_heading level0 col0" >is_pii</th>
#       <th id="T_faeb6_level0_col1" class="col_heading level0 col1" >prop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faeb6_level0_row0" class="row_heading level0 row0" >yes</th>
#       <td id="T_faeb6_row0_col0" class="data row0 col0" >766</td>
#       <td id="T_faeb6_row0_col1" class="data row0 col1" >30.6%</td>
#     </tr>
#     <tr>
#       <th id="T_faeb6_level0_row1" class="row_heading level0 row1" >maybe</th>
#       <td id="T_faeb6_row1_col0" class="data row1 col0" >165</td>
#       <td id="T_faeb6_row1_col1" class="data row1 col1" >6.6%</td>
#     </tr>
#     <tr>
#       <th id="T_faeb6_level0_row2" class="row_heading level0 row2" >no</th>
#       <td id="T_faeb6_row2_col0" class="data row2 col0" >1569</td>
#       <td id="T_faeb6_row2_col1" class="data row2 col1" >62.8%</td>
#     </tr>
#   </tbody>
# </table>

# %%
dlp_presidio_comp.groupby(level=-1).sum()
# Out:
#         dlp_flagged  dlp_not_flagged  presidio_flagged  presidio_not_flagged
# is_pii
# yes             766                0               524                   242
# maybe           150               15                76                    89
# no              584              985               106                  1463
#
# [3 rows x 4 columns]

# %%
dlp_presidio_comp.swaplevel().sort_index()
# Out:
#                          dlp_flagged  dlp_not_flagged  presidio_flagged  \
# is_pii grouping
# yes    num_flagged_high          276                0                40
#        num_flagged_med           466                0               464
#        num_flagged_low            24                0                20
# maybe  num_flagged_high           13                0                 1
#        num_flagged_med            12                0                 7
#        num_flagged_low           125                0                64
#        num_unflagged               0               12                 4
#        nonnum                      0                3                 0
# no     num_flagged_high          211                0                 4
#        num_flagged_med            19                0                11
#        num_flagged_low           354                0                88
#        num_unflagged               0              488                 3
#        nonnum                      0              497                 0
#
#                          presidio_not_flagged
# is_pii grouping
# yes    num_flagged_high                   236
#        num_flagged_med                      2
#        num_flagged_low                      4
# maybe  num_flagged_high                    12
#        num_flagged_med                      5
#        num_flagged_low                     61
#        num_unflagged                        8
#        nonnum                               3
# no     num_flagged_high                   207
#        num_flagged_med                      8
#        num_flagged_low                    266
#        num_unflagged                      485
#        nonnum                             497
#
# [13 rows x 4 columns]

# %% [markdown]
# #### Observations
#
# __Numeric flagged high:__
# - Yes PII: mostly street addresses (some with phone numbers) & IP addresses,
#     * DLP detects pretty much all
#     * Presidio doesn't have street address detection and doesn't flag any address
#         + generally flags phone numbers (\~0.4) and IP addresses (\~0.6)
#         + some false positive flagging ZIP codes or phone numbers as SSN/DL, although with low confidence (0.01-0.05)
# - Maybe PII: partial addresses (eg. street only, no city)
#     * DLP flags all
#     * Presidio none (except for low-confidence false positive)
# - Not PII: generally location-related, some URL-like strings
#     * eg. city/zip only, institution/city/zip, query/zip, or even general queries containing numbers
#     * DLP flags all as LIKELY address
#     * Presidio correctly ignores them except for a couple of low-confidence false positives
#
#
# __Numeric flagged med:__
# - Yes PII: IP addresses & phone numbers
#     * DLP correctly flags all
#     * Presidio generally flags all correctly
#         + phone numbers (0.4) and IP addresses (0.6)
# - Maybe PII: some long numbers without context: could be financial/ID or else product/record numbers
#     * DLP generally flags them as credit card (prob correct) or phone number (prob wrong)
#     * Presidio flags a few as phone numbers, some as other ID numbers, the rest unflagged
# - Not PII: generally product ID numbers
#     * DLP generally flags as phone number
#     * Presidio ignores some and flags some as phone/credit card
#
#
# __Numeric flagged low:__
# - Yes PII: IP addresses & phone numbers (non-traditional format), some online order/booking numbers
#     * DLP flags almost all as phone numbers (some incorrectly)
#     * Presidio generally does a good job, flagging phone numbers and some
# - Maybe PII: various long numeric strings, eg tokens, ID numbers, phone numbers without area codes, 9-digit numbers (could be ZIP codes)
#     * DLP flags as phone/credit card/ID
#     * Presidio flags in various categories, many with low confidence
# - Not PII: general queries which include numbers, eg. dates, model IDs
#     * DLP generally flags most as phone number, some as SSN/ID number
#     * Presidio flags some as phone number, most as ID numbers with low confidence
#
#
# __Numeric unflagged:__
# - Maybe PII: partial addresses (eg. street only, no city), URL tokens
#     * Presidio flags some as low-confidence ID numbers
# - Not PII: general queries which include numbers
#     * Presidio flags a couple with low confidence
#
#
# __Non-numeric:__
# - Maybe PII: institution name + city/state (eg. hotel)
#     * never flagged
# - Not PII:
#     * never flagged

# %%
(
    num_aol_labeled
    .query("grouping == 'num_flagged_high' and is_pii == 'yes'")[:10]
)
# Out:
#                                                                                                                                                                                                                                 query  \
# 3251  000&1rc l1aaa&cl en&ct na&1si navt&rsres 1&1y us&1ffi &1l &1g &1pl &1v address&1n &1pn &1a 13391 el prado ave&1c garden grove&1s ca&1z 92840-6255&panelbtn 1&2y us&2ffi &2l &2g &2pl &2v &2n &2pn &2a &2c orange&2s ca&2z 92869
# 3600                                                                                                                                                                                        1 100 sanjuan ave.redlands ca 92374 92374
# 4365                                                                                                                                                                                    1003 tenth street modesto california zip code
# 4472                                                                                                                                                                                                   1015 yahoola road dahlonega ga
# 4566                                                                                                                                                                                                     103 state street marlboro ma
# 4634                                                                                                                                                                                                   104 monroe lane egg harbor twp
# 4689                                                                                                                                                                                                         1040 moore st tribeca ny
# 4697                                                                                                                                                                                             1040 waverly ave holtsville ny 10742
# 4698                                                                                                                                                                                              1040 waverly ave hotsville ny 10742
# 4872                                                                                                                                                                                                107 briarwood terde soto mo 63020
#
#       has_num                            presidio  \
# 3251     True        [(US_SSN, 92840-6255, 0.05)]
# 3600     True  [(PHONE_NUMBER, 92374 92374, 0.4)]
# 4365     True                                None
# 4472     True                                None
# 4566     True                                None
# 4634     True                                None
# 4689     True                                None
# 4697     True                                None
# 4698     True                                None
# 4872     True                                None
#
#                                                                                                                                     dlp  \
# 3251  [(PHONE_NUMBER, 92840-6255, UNLIKELY), (STREET_ADDRESS, 13391 el prado ave&1c garden grove&1s ca&1z 92840-6255&panelbtn, LIKELY)]
# 3600                                                                      [(STREET_ADDRESS, 100 sanjuan ave.redlands ca 92374, LIKELY)]
# 4365                                                                   [(STREET_ADDRESS, 1003 tenth street modesto california, LIKELY)]
# 4472                                                                         [(STREET_ADDRESS, 1015 yahoola road dahlonega ga, LIKELY)]
# 4566                                                                           [(STREET_ADDRESS, 103 state street marlboro ma, LIKELY)]
# 4634                                                                                        [(STREET_ADDRESS, 104 monroe lane, LIKELY)]
# 4689                                                                               [(STREET_ADDRESS, 1040 moore st tribeca ny, LIKELY)]
# 4697                                                                   [(STREET_ADDRESS, 1040 waverly ave holtsville ny 10742, LIKELY)]
# 4698                                                                    [(STREET_ADDRESS, 1040 waverly ave hotsville ny 10742, LIKELY)]
# 4872                                                                      [(STREET_ADDRESS, 107 briarwood terde soto mo 63020, LIKELY)]
#
#      dlp_max_score is_pii          grouping
# 3251          high    yes  num_flagged_high
# 3600          high    yes  num_flagged_high
# 4365          high    yes  num_flagged_high
# 4472          high    yes  num_flagged_high
# 4566          high    yes  num_flagged_high
# 4634          high    yes  num_flagged_high
# 4689          high    yes  num_flagged_high
# 4697          high    yes  num_flagged_high
# 4698          high    yes  num_flagged_high
# 4872          high    yes  num_flagged_high
#
# [10 rows x 7 columns]

# %% [markdown]
# ### PII types

# %%
def scan_results_contain(x, types):
    if not x:
        return False
    if isinstance(types, str):
        types = [types]
    for y in x:
        if y.type in types:
            return True
    return False

# %%
num_aol_labeled_types = num_aol_labeled.assign(
    address_dlp=num_aol_labeled["dlp"].map(lambda x: scan_results_contain(x, "STREET_ADDRESS")),
    ip_dlp=num_aol_labeled["dlp"].map(lambda x: scan_results_contain(x, "IP_ADDRESS")),
    phone_dlp=num_aol_labeled["dlp"].map(lambda x: scan_results_contain(x, "PHONE_NUMBER")),
    other_dlp=lambda x: ~x["address_dlp"] & ~x["ip_dlp"] & ~x["phone_dlp"] & x["dlp"].notna(),
    ip_presidio=num_aol_labeled["presidio"].map(lambda x: scan_results_contain(x, "IP_ADDRESS")),
    phone_presidio=num_aol_labeled["presidio"].map(lambda x: scan_results_contain(x, "PHONE_NUMBER")),
    other_presidio=lambda x: ~x["ip_presidio"] & ~x["phone_presidio"] & x["presidio"].notna(),
)

# %% [markdown]
# Addresses:

# %%
(
    num_aol_labeled_types
    .query("address_dlp")["is_pii"]
    .value_counts()
    .sort_index()
    .to_frame()
    .assign(prop=lambda x: x["is_pii"] / x["is_pii"].sum())
    .style.format({"prop": "{:.1%}"})
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1723e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1723e_level0_col0" class="col_heading level0 col0" >is_pii</th>
#       <th id="T_1723e_level0_col1" class="col_heading level0 col1" >prop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1723e_level0_row0" class="row_heading level0 row0" >yes</th>
#       <td id="T_1723e_row0_col0" class="data row0 col0" >251</td>
#       <td id="T_1723e_row0_col1" class="data row0 col1" >53.0%</td>
#     </tr>
#     <tr>
#       <th id="T_1723e_level0_row1" class="row_heading level0 row1" >maybe</th>
#       <td id="T_1723e_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_1723e_row1_col1" class="data row1 col1" >2.7%</td>
#     </tr>
#     <tr>
#       <th id="T_1723e_level0_row2" class="row_heading level0 row2" >no</th>
#       <td id="T_1723e_row2_col0" class="data row2 col0" >210</td>
#       <td id="T_1723e_row2_col1" class="data row2 col1" >44.3%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# IP addresses:

# %%
pivot_detection_counts(
(
    num_aol_labeled_types
    .groupby([
        num_aol_labeled_types["ip_dlp"].astype(str),
        num_aol_labeled_types["ip_presidio"].astype(str),
        "is_pii",
    ])
    .size()
    .reset_index(name="count")
)
    ,
    index=["ip_dlp", "ip_presidio"],
    columns="is_pii"
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0fd92">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fd92_level0_col0" class="col_heading level0 col0" colspan="4">count</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >is_pii</th>
#       <th id="T_0fd92_level1_col0" class="col_heading level1 col0" >yes</th>
#       <th id="T_0fd92_level1_col1" class="col_heading level1 col1" >maybe</th>
#       <th id="T_0fd92_level1_col2" class="col_heading level1 col2" >no</th>
#       <th id="T_0fd92_level1_col3" class="col_heading level1 col3" >total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ip_dlp</th>
#       <th class="index_name level1" >ip_presidio</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fd92_level0_row0" class="row_heading level0 row0" rowspan="2">False</th>
#       <th id="T_0fd92_level1_row0" class="row_heading level1 row0" >False</th>
#       <td id="T_0fd92_row0_col0" class="data row0 col0" >556</td>
#       <td id="T_0fd92_row0_col1" class="data row0 col1" >165</td>
#       <td id="T_0fd92_row0_col2" class="data row0 col2" >1,569</td>
#       <td id="T_0fd92_row0_col3" class="data row0 col3" >2,290</td>
#     </tr>
#     <tr>
#       <th id="T_0fd92_level1_row1" class="row_heading level1 row1" >True</th>
#       <td id="T_0fd92_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_0fd92_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_0fd92_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0fd92_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0fd92_level0_row2" class="row_heading level0 row2" rowspan="2">True</th>
#       <th id="T_0fd92_level1_row2" class="row_heading level1 row2" >False</th>
#       <td id="T_0fd92_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_0fd92_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_0fd92_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_0fd92_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0fd92_level1_row3" class="row_heading level1 row3" >True</th>
#       <td id="T_0fd92_row3_col0" class="data row3 col0" >210</td>
#       <td id="T_0fd92_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_0fd92_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_0fd92_row3_col3" class="data row3 col3" >210</td>
#     </tr>
#     <tr>
#       <th id="T_0fd92_level0_row4" class="row_heading level0 row4" >total</th>
#       <th id="T_0fd92_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_0fd92_row4_col0" class="data row4 col0" >766</td>
#       <td id="T_0fd92_row4_col1" class="data row4 col1" >165</td>
#       <td id="T_0fd92_row4_col2" class="data row4 col2" >1,569</td>
#       <td id="T_0fd92_row4_col3" class="data row4 col3" >2,500</td>
#     </tr>
#   </tbody>
# </table>

# %%
(
    num_aol_labeled_types
    .query("is_pii == 'yes'")
    .groupby(["address_dlp", "ip_dlp", "phone_dlp", "other_dlp", "ip_presidio", "phone_presidio", "other_presidio"])
    .size()
    .to_frame(name="count")
)
# Out:
#                                                                                   count
# address_dlp ip_dlp phone_dlp other_dlp ip_presidio phone_presidio other_presidio
# False       False  False     True      False       False          True                2
#                    True      False     False       False          False               6
#                                                                   True                1
#                                                    True           False             296
#             True   False     False     True        False          False             137
#                                                    True           False              72
#                    True      False     True        False          False               1
# True        False  False     False     False       False          False             233
#                                                    True           False               2
#                    True      False     False       False          False               3
#                                                                   True                8
#                                                    True           False               5
#
# [12 rows x 1 columns]

# %%
num_aol_labeled_types
# Out:
#                                                                                                                                                                                                                                                     query  \
# 335                                                                                                                                                                          ----- forwarded by jackie sloan res clubcorp us on 02 27 2006 03 28 pm -----
# 350      -----------------forwarded message subj fwd some thoughts 4 u date 4 12 2006 1 42 12 p.m. central daylight time from gdvtek to gdvtek -----------------forwarded message subj fwd some thoughts 4 u date 4 12 2006 1 41 30 p.m. central daylight
# 547                                                                                                                                                                                                                            ...............0000.00000.
# 679                                                                                                                                                                                                                                                    .7
# 680                                                                                                                                                                                                                                        .71.244.90.56.
# ...                                                                                                                                                                                                                                                   ...
# 188720                                                                                                                                                                                                                                   chinese diet tea
# 1023870                                                                                                                                                                                                                              wood filing cabinets
# 395072                                                                                                                                                                                                                                               gria
# 164596                                                                                                                                                                                                                                    cartoon.network
# 920088                                                                                                                                                                                                                                           the unit
#
#          has_num                                 presidio  \
# 335         True  [(PHONE_NUMBER, 02 27 2006 03 28, 0.4)]
# 350         True                                     None
# 547         True                                     None
# 679         True                                     None
# 680         True        [(IP_ADDRESS, 71.244.90.56, 0.6)]
# ...          ...                                      ...
# 188720     False                                     None
# 1023870    False                                     None
# 395072     False                                     None
# 164596     False                                     None
# 920088     False                                     None
#
#                                                                                             dlp  \
# 335                                                [(PHONE_NUMBER, 02 27 2006 03 28, UNLIKELY)]
# 350      [(PHONE_NUMBER, 12 2006 1 42 12, UNLIKELY), (PHONE_NUMBER, 12 2006 1 41 30, UNLIKELY)]
# 547                                                      [(PHONE_NUMBER, 0000.00000, UNLIKELY)]
# 679                                                                                        None
# 680                                                      [(IP_ADDRESS, 71.244.90.56, POSSIBLE)]
# ...                                                                                         ...
# 188720                                                                                     None
# 1023870                                                                                    None
# 395072                                                                                     None
# 164596                                                                                     None
# 920088                                                                                     None
#
#         dlp_max_score is_pii         grouping  address_dlp  ip_dlp  phone_dlp  \
# 335               low     no  num_flagged_low        False   False       True
# 350               low     no  num_flagged_low        False   False       True
# 547               low     no  num_flagged_low        False   False       True
# 679              None     no    num_unflagged        False   False      False
# 680               med    yes  num_flagged_med        False    True      False
# ...               ...    ...              ...          ...     ...        ...
# 188720           None     no           nonnum        False   False      False
# 1023870          None     no           nonnum        False   False      False
# 395072           None     no           nonnum        False   False      False
# 164596           None     no           nonnum        False   False      False
# 920088           None     no           nonnum        False   False      False
#
#          other_dlp  ip_presidio  phone_presidio  other_presidio
# 335          False        False            True           False
# 350          False        False           False           False
# 547          False        False           False           False
# 679          False        False           False           False
# 680          False         True           False           False
# ...            ...          ...             ...             ...
# 188720       False        False           False           False
# 1023870      False        False           False           False
# 395072       False        False           False           False
# 164596       False        False           False           False
# 920088       False        False           False           False
#
# [2500 rows x 14 columns]
