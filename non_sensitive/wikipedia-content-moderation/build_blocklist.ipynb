# %% [markdown]
# # Build a blocklist from seeds
#
# Build a list of NSFW Wikipedia categories to block starting from a set of seeds.
#
# This notebook requires the category index dataset to have been built previously by running `build_category_index.ipynb`.

# %%
from pathlib import Path

import pandas as pd

from wikipedia_utils.utils import display_pd
from wikipedia_utils import category

# %% [markdown]
# `DATA_DIR` should be set to the dir where the category index files were written.

# %%
DATA_DIR = Path("category_data")
SEED_FILE = "moderation_category_seeds.yml"
NEW_BLOCKLIST_CSV = DATA_DIR / "blocklist_cats.csv"
CURRENT_BLOCKLIST_CSV = "blocklist_cats.csv"

# %% [markdown]
# ## Load the seed file
#
# The final list of categories to block is built by expanding on a manually curated set of seeds.
# The seeds are defined in a YAML file and consist of inclusions and exclusions, either exact category names and regexes, for each topic area.
# These seeds have been chosen by interactively exploring Wikipedia categories relevant to the topic areas of interest using the tools described in `explore_categories.ipynb`.
#
# The seed file has the following format. For each topic listing, all keys except for `topic` are optional.
# ```yaml
# blocklist:
#   - topic: <topic_key>
#     seed_categories:
#       - <exact category name>
#     seed_re:
#       - <regex to match category names>
#     ignore_categories:
#       - <exact category name>
#     ignore_re:
#       - <regex to match category names>
#     max_level: <max depth to search category digraph>
# ```

# %%
seed_dict = category.load_blocklist_seeds(SEED_FILE)

# %% [markdown]
# We can view the seed list as a table with columns for each NSFW topic.

# %%
display_pd(pd.DataFrame(seed_dict).drop("topic"))
# Out:
#                                  profanity              pejoratives
# seed_categories                [Profanity]                      NaN  \
# ignore_categories  [Works about profanity]             [Barbarians]
# seed_re                                NaN  [\bslurs, \bpejorative]
# ignore_re                              NaN               [\beskimo]
# max_level                              NaN                      NaN
#
#                                                                                                                                                                             cruelty
# seed_categories                                                                                                                                                           [Torture]  \
# ignore_categories  [Castrated people, Operation Condor, Crucifixion, Amputations, Fictional torturers, Works about torture, Guantanamo Bay detention camp, People of the Dirty War]
# seed_re                                                                                                                                                                         NaN
# ignore_re                                                                                                            [\banti-torture\b, \btorture victims?\b, \bhuman rights activ]
# max_level                                                                                                                                                                       NaN
#
#                                                                                                                                                                                                                                                                                                   child_abuse
# seed_categories                                                                                                                                                                                                                                                                                 [Child abuse]  \
# ignore_categories  [Child abuse law, Child abuse-related organizations, Anti-pedophile activism, Child labour, Displacement of indigenous children, School bullying, QAnon, Works about child abuse, Feral children, Fiction about child murder, Filicides, Fictional murderers of children, Child sacrifice]
# seed_re                                                                                                                                                                                                                                                                                                   NaN
# ignore_re                                                                                                                                                                                                                                                                                                 NaN
# max_level                                                                                                                                                                                                                                                                                                 NaN
#
#                                                                                                                                                                                                                                              sexually_explicit
# seed_categories    [Sex manuals, Incest, Sexual emotions, Prostitution, Sexuality-related lists, Machine sex, Orgasm, Sexual fetishism, Pornography, Paraphilias, Sexual slang, Personal lubricants, Sexual fantasies, Sex toys, Sexual violence, Sexual acts]  \
# ignore_categories                                                                                                                            [One Thousand and One Nights, Aphrodite, Game of Thrones, Erotic Liquid Culture members, Swedish Erotica members]
# seed_re                                                                                                                                                                                                                               [\bpornograph, \berotic]
# ignore_re                                                                                  [\banti\W(child )?porn, \blaw.+\bporn, \bporn.+\blaw, \blaw.+\bprostitut, \bprostitut.+\blaw, \banti\Wprostitut, \bsex comedy\b, \bmytholog, \bNew Pornographers\b]
# max_level                                                                                                                                                                                                                                                  NaN
#
#                         hateful_ideologies
# seed_categories        [White nationalism]
# ignore_categories  [Works about apartheid]
# seed_re                                NaN
# ignore_re                              NaN
# max_level                                4

# %% [markdown]
# ## Build blocklists for individual topics
#
# To build a list of categories that will be used as a blocklist:
#
# 1. Identify all categories matched by the seeds, either exact category names or matching regexes. If seeds match both a subcategory and its parent, keep only the parent to ensure a cleaner level structure.
# 2. For each of these, identify all their subcategories, ignoring specified exact category names or matching regexes.
# 3. Repeat step 2 for all newly identified subcategories, until the depth cutoff is reached, or no more subcategories are available.
#
# We can do this for individual topic specs included in the seed file. This is useful for verifying the final list of categories that will be included in the blocklist.

# %%
ci = category.CategoryIndex("category_data")

# %% [markdown]
# Individual blocklists for each category should be manually inspected to make sure they cover the desired set of topics.

# %%
# %%time

ci.build_category_list_for_topic(seed_dict["profanity"])
# Out:
# CPU times: user 1.33 s, sys: 168 ms, total: 1.5 s
# Wall time: 1.52 s
#                      name       seed                 parent  level      topic
# 0               Profanity  Profanity                   None      0  profanity
# 1   Profanity by language  Profanity              Profanity      1  profanity
# 2     Cantonese profanity  Profanity  Profanity by language      2  profanity
# 3       English profanity  Profanity  Profanity by language      2  profanity
# 4       Finnish profanity  Profanity  Profanity by language      2  profanity
# 5        French profanity  Profanity  Profanity by language      2  profanity
# 6        German profanity  Profanity  Profanity by language      2  profanity
# 7         Hindi profanity  Profanity  Profanity by language      2  profanity
# 8        Polish profanity  Profanity  Profanity by language      2  profanity
# 9       Russian profanity  Profanity  Profanity by language      2  profanity
# 10      Spanish profanity  Profanity  Profanity by language      2  profanity

# %% [markdown]
# ## Build full blocklist
#
# Finally, we build the full blocklist for the entire seed list.
# This is done using the same method as above, across all topics, removing any duplicates.
# The result is written directly to a CSV file.

# %%
# %%time

ci.build_full_category_list(seed_dict, NEW_BLOCKLIST_CSV)
# Out:
# CPU times: user 22.9 s, sys: 2.01 s, total: 24.9 s
# Wall time: 25 s

# %% [markdown]
# Take a look at the generated blocklist of categories.

# %%
blocklist_cats = pd.read_csv(NEW_BLOCKLIST_CSV)

# %%
len(blocklist_cats)
# Out:
# 3274

# %% [markdown]
# Compute some info for each topic:

# %%
blocklist_cats.groupby("topic").agg(
    num_categories=pd.NamedAgg("name", "size"),
    max_level=pd.NamedAgg("level", "max")
)
# Out:
#                     num_categories  max_level
# topic
# child_abuse                    402          8
# cruelty                        132          7
# hateful_ideologies             303          4
# pejoratives                     32          4
# profanity                       11          2
# sexually_explicit             2394         10

# %% [markdown]
# __NSFW content warning!__
#
# Take a look at some of the categories

# %%
blocklist_cats.sample(20)
# Out:
#                                                    name               seed
# 1528                       Sexual harassment journalism    Sexual violence  \
# 2248                            Pakistani sex offenders    Sexual violence
# 2502                              Pornography in Nevada             Erotic
# 3129                                   Nazi politicians  White nationalism
# 1468                                Rape in South Korea    Sexual violence
# 1603                              German erotic artists             Erotic
# 2044                              Courtesans from Paris       Prostitution
# 94                                     Torture in Spain            Torture
# 2035              Films about prostitution in Australia       Prostitution
# 690                                           Burlesque             Erotic
# 1878                 German pornographic film producers             Erotic
# 2714  Activists for victims of sexual abuse in the C...    Sexual violence
# 3084                       White nationalism in England  White nationalism
# 2395                          French erotic drama films             Erotic
# 75                                   Torture in Bahrain            Torture
# 2870                 Xtreme Pro Wrestling championships             Erotic
# 231                    Books about satanic ritual abuse        Child abuse
# 2979                           White nationalist groups  White nationalism
# 3234                                Fictional neo-Nazis  White nationalism
# 2497         American pornographic film actors by state             Erotic
#
#                                          parent  level               topic
# 1528                          Sexual harassment      3   sexually_explicit
# 2248               Sex offenders by nationality      4   sexually_explicit
# 2502  Pornography in the United States by state      5   sexually_explicit
# 3129                         White supremacists      3  hateful_ideologies
# 1468                            Rape by country      3   sexually_explicit
# 1603              Erotic artists by nationality      4   sexually_explicit
# 2044                          French courtesans      4   sexually_explicit
# 94                           Torture by country      2             cruelty
# 2035      Works about prostitution in Australia      4   sexually_explicit
# 690                                Erotic dance      2   sexually_explicit
# 1878                Pornographic film producers      4   sexually_explicit
# 2714              Sexual abuse victim advocates      5   sexually_explicit
# 3084    White nationalism in the United Kingdom      3  hateful_ideologies
# 2395              Erotic drama films by country      5   sexually_explicit
# 75                           Torture by country      2             cruelty
# 2870                       Xtreme Pro Wrestling      7   sexually_explicit
# 231                        Satanic ritual abuse      2         child_abuse
# 2979                          White nationalism      1  hateful_ideologies
# 3234                                  Neo-Nazis      4  hateful_ideologies
# 2497  Pornography in the United States by state      5   sexually_explicit

# %% [markdown]
# ## Compare against previous blocklist
#
# When we recompute the blocklist using a new category dump, we will want to see what changed relative to the previous version.

# %%
prev_bl_cats = pd.read_csv(CURRENT_BLOCKLIST_CSV)
new_bl_cats = pd.read_csv(NEW_BLOCKLIST_CSV)

# %%
###-------------------------------
### DELETEME
### This is only needed temporarily to convert the initial list to the new format.

prev_seeds = prev_bl_cats["seed"].unique()

prev_seed_topic = {}
for s in prev_seeds:
    for v in seed_dict.values():
        s_cats = [c.lower() for c in v.get("seed_categories", [])]
        s_re = [r.replace("\\b", "") for r in v.get("seed_re", [])]
        if s.lower() in s_cats or s.lower() in s_re:
            prev_seed_topic[s] = v["topic"]
            break

prev_bl_cats["topic"] = prev_bl_cats["seed"].map(prev_seed_topic)
prev_bl_cats = prev_bl_cats.drop(columns="max_level")

###-------------------------------

# %% [markdown]
# How do the two lists differ?

# %%
bl_cats_comb = pd.concat(
    [prev_bl_cats.assign(type="previous"), new_bl_cats.assign(type="new")],
    ignore_index=True,
)

# %%
bl_cats_comb["type"].value_counts()
# Out:
# type
# previous    3385
# new         3274
# Name: count, dtype: int64

# %%
(
    bl_cats_comb
    .groupby(["type", "topic"])
    .agg(num_categories=pd.NamedAgg("name", "size"), max_level=pd.NamedAgg("level", "max"))
    .unstack(level=0)
)
# Out:
#                    num_categories          max_level
# type                          new previous       new previous
# topic
# child_abuse                   402      391         8        8
# cruelty                       132      219         7        8
# hateful_ideologies            303      298         4        4
# pejoratives                    32       38         4        4
# profanity                      11       11         2        2
# sexually_explicit            2394     2428        10       10

# %% [markdown]
# Compute a diff between the two lists.

# %%
bl_diff = category.compare_categories_lists(prev_bl_cats, new_bl_cats)

# %% [markdown]
# Some categories have been added to or removed from topics, or else their details (seed/parent/level) have changed.
# In some cases, a category may move from one topic to another, but remains on the blocklist.
# These changes can be due to edits made to Wikipedia, or updates we made to our seed list.

# %%
bl_diff["diff"].value_counts().sort_index()
# Out:
# diff
# added       34
# changed     71
# moved       42
# removed    145
# Name: count, dtype: int64

# %% [markdown]
# __NSFW content warning!__
#
# List the categories that differ. Categories that have moved to a different topic are shown in blue.

# %%
display_pd(category.style_diff(bl_diff))
# Out:
# <style type="text/css">
# #T_bd82e_row0_col2, #T_bd82e_row0_col3, #T_bd82e_row0_col6, #T_bd82e_row0_col7, #T_bd82e_row1_col2, #T_bd82e_row1_col3, #T_bd82e_row1_col6, #T_bd82e_row1_col7, #T_bd82e_row2_col2, #T_bd82e_row2_col3, #T_bd82e_row2_col6, #T_bd82e_row2_col7, #T_bd82e_row3_col2, #T_bd82e_row3_col3, #T_bd82e_row3_col6, #T_bd82e_row3_col7, #T_bd82e_row18_col2, #T_bd82e_row18_col3, #T_bd82e_row18_col6, #T_bd82e_row18_col7, #T_bd82e_row23_col2, #T_bd82e_row23_col6, #T_bd82e_row127_col2, #T_bd82e_row127_col6, #T_bd82e_row128_col2, #T_bd82e_row128_col6, #T_bd82e_row129_col2, #T_bd82e_row129_col6, #T_bd82e_row130_col2, #T_bd82e_row130_col3, #T_bd82e_row130_col6, #T_bd82e_row130_col7, #T_bd82e_row132_col2, #T_bd82e_row132_col6, #T_bd82e_row133_col2, #T_bd82e_row133_col3, #T_bd82e_row133_col6, #T_bd82e_row133_col7, #T_bd82e_row200_col2, #T_bd82e_row200_col3, #T_bd82e_row200_col6, #T_bd82e_row200_col7, #T_bd82e_row201_col2, #T_bd82e_row201_col3, #T_bd82e_row201_col6, #T_bd82e_row201_col7, #T_bd82e_row203_col3, #T_bd82e_row203_col7, #T_bd82e_row206_col3, #T_bd82e_row206_col7, #T_bd82e_row207_col3, #T_bd82e_row207_col7, #T_bd82e_row210_col2, #T_bd82e_row210_col6, #T_bd82e_row211_col3, #T_bd82e_row211_col7, #T_bd82e_row212_col3, #T_bd82e_row212_col7, #T_bd82e_row213_col3, #T_bd82e_row213_col7, #T_bd82e_row214_col3, #T_bd82e_row214_col7, #T_bd82e_row216_col3, #T_bd82e_row216_col7, #T_bd82e_row217_col2, #T_bd82e_row217_col6, #T_bd82e_row218_col3, #T_bd82e_row218_col7, #T_bd82e_row219_col3, #T_bd82e_row219_col7, #T_bd82e_row220_col3, #T_bd82e_row220_col7, #T_bd82e_row222_col3, #T_bd82e_row222_col7, #T_bd82e_row223_col3, #T_bd82e_row223_col7, #T_bd82e_row224_col3, #T_bd82e_row224_col7, #T_bd82e_row225_col3, #T_bd82e_row225_col7, #T_bd82e_row226_col3, #T_bd82e_row226_col7, #T_bd82e_row227_col3, #T_bd82e_row227_col7, #T_bd82e_row228_col3, #T_bd82e_row228_col7, #T_bd82e_row229_col2, #T_bd82e_row229_col6, #T_bd82e_row230_col3, #T_bd82e_row230_col7, #T_bd82e_row231_col3, #T_bd82e_row231_col7, #T_bd82e_row232_col2, #T_bd82e_row232_col3, #T_bd82e_row232_col6, #T_bd82e_row232_col7, #T_bd82e_row233_col2, #T_bd82e_row233_col6, #T_bd82e_row235_col3, #T_bd82e_row235_col7, #T_bd82e_row236_col3, #T_bd82e_row236_col7, #T_bd82e_row237_col3, #T_bd82e_row237_col7, #T_bd82e_row238_col3, #T_bd82e_row238_col7, #T_bd82e_row239_col3, #T_bd82e_row239_col7, #T_bd82e_row242_col3, #T_bd82e_row242_col7, #T_bd82e_row243_col3, #T_bd82e_row243_col7, #T_bd82e_row244_col2, #T_bd82e_row244_col3, #T_bd82e_row244_col6, #T_bd82e_row244_col7, #T_bd82e_row245_col3, #T_bd82e_row245_col7, #T_bd82e_row246_col3, #T_bd82e_row246_col7, #T_bd82e_row247_col3, #T_bd82e_row247_col7, #T_bd82e_row248_col3, #T_bd82e_row248_col7, #T_bd82e_row249_col1, #T_bd82e_row249_col2, #T_bd82e_row249_col3, #T_bd82e_row249_col5, #T_bd82e_row249_col6, #T_bd82e_row249_col7, #T_bd82e_row250_col3, #T_bd82e_row250_col7, #T_bd82e_row251_col3, #T_bd82e_row251_col7, #T_bd82e_row252_col3, #T_bd82e_row252_col7, #T_bd82e_row253_col3, #T_bd82e_row253_col7, #T_bd82e_row254_col3, #T_bd82e_row254_col7, #T_bd82e_row255_col3, #T_bd82e_row255_col7, #T_bd82e_row256_col3, #T_bd82e_row256_col7, #T_bd82e_row257_col3, #T_bd82e_row257_col7, #T_bd82e_row258_col3, #T_bd82e_row258_col7, #T_bd82e_row259_col3, #T_bd82e_row259_col7, #T_bd82e_row260_col3, #T_bd82e_row260_col7, #T_bd82e_row261_col3, #T_bd82e_row261_col7, #T_bd82e_row262_col3, #T_bd82e_row262_col7, #T_bd82e_row263_col1, #T_bd82e_row263_col3, #T_bd82e_row263_col5, #T_bd82e_row263_col7, #T_bd82e_row264_col3, #T_bd82e_row264_col7, #T_bd82e_row265_col3, #T_bd82e_row265_col7, #T_bd82e_row266_col3, #T_bd82e_row266_col7, #T_bd82e_row267_col3, #T_bd82e_row267_col7, #T_bd82e_row268_col3, #T_bd82e_row268_col7 {
#   background-color: gold;
# }
# #T_bd82e_row4_col0, #T_bd82e_row4_col1, #T_bd82e_row4_col2, #T_bd82e_row4_col3, #T_bd82e_row17_col0, #T_bd82e_row17_col1, #T_bd82e_row17_col2, #T_bd82e_row17_col3, #T_bd82e_row19_col0, #T_bd82e_row19_col1, #T_bd82e_row19_col2, #T_bd82e_row19_col3, #T_bd82e_row20_col0, #T_bd82e_row20_col1, #T_bd82e_row20_col2, #T_bd82e_row20_col3, #T_bd82e_row21_col0, #T_bd82e_row21_col1, #T_bd82e_row21_col2, #T_bd82e_row21_col3, #T_bd82e_row22_col0, #T_bd82e_row22_col1, #T_bd82e_row22_col2, #T_bd82e_row22_col3, #T_bd82e_row24_col0, #T_bd82e_row24_col1, #T_bd82e_row24_col2, #T_bd82e_row24_col3, #T_bd82e_row25_col0, #T_bd82e_row25_col1, #T_bd82e_row25_col2, #T_bd82e_row25_col3, #T_bd82e_row26_col0, #T_bd82e_row26_col1, #T_bd82e_row26_col2, #T_bd82e_row26_col3, #T_bd82e_row27_col0, #T_bd82e_row27_col1, #T_bd82e_row27_col2, #T_bd82e_row27_col3, #T_bd82e_row28_col0, #T_bd82e_row28_col1, #T_bd82e_row28_col2, #T_bd82e_row28_col3, #T_bd82e_row29_col0, #T_bd82e_row29_col1, #T_bd82e_row29_col2, #T_bd82e_row29_col3, #T_bd82e_row30_col0, #T_bd82e_row30_col1, #T_bd82e_row30_col2, #T_bd82e_row30_col3, #T_bd82e_row31_col0, #T_bd82e_row31_col1, #T_bd82e_row31_col2, #T_bd82e_row31_col3, #T_bd82e_row32_col0, #T_bd82e_row32_col1, #T_bd82e_row32_col2, #T_bd82e_row32_col3, #T_bd82e_row33_col0, #T_bd82e_row33_col1, #T_bd82e_row33_col2, #T_bd82e_row33_col3, #T_bd82e_row34_col0, #T_bd82e_row34_col1, #T_bd82e_row34_col2, #T_bd82e_row34_col3, #T_bd82e_row35_col0, #T_bd82e_row35_col1, #T_bd82e_row35_col2, #T_bd82e_row35_col3, #T_bd82e_row36_col0, #T_bd82e_row36_col1, #T_bd82e_row36_col2, #T_bd82e_row36_col3, #T_bd82e_row37_col0, #T_bd82e_row37_col1, #T_bd82e_row37_col2, #T_bd82e_row37_col3, #T_bd82e_row38_col0, #T_bd82e_row38_col1, #T_bd82e_row38_col2, #T_bd82e_row38_col3, #T_bd82e_row39_col0, #T_bd82e_row39_col1, #T_bd82e_row39_col2, #T_bd82e_row39_col3, #T_bd82e_row40_col0, #T_bd82e_row40_col1, #T_bd82e_row40_col2, #T_bd82e_row40_col3, #T_bd82e_row41_col0, #T_bd82e_row41_col1, #T_bd82e_row41_col2, #T_bd82e_row41_col3, #T_bd82e_row42_col0, #T_bd82e_row42_col1, #T_bd82e_row42_col2, #T_bd82e_row42_col3, #T_bd82e_row43_col0, #T_bd82e_row43_col1, #T_bd82e_row43_col2, #T_bd82e_row43_col3, #T_bd82e_row44_col0, #T_bd82e_row44_col1, #T_bd82e_row44_col2, #T_bd82e_row44_col3, #T_bd82e_row45_col0, #T_bd82e_row45_col1, #T_bd82e_row45_col2, #T_bd82e_row45_col3, #T_bd82e_row46_col0, #T_bd82e_row46_col1, #T_bd82e_row46_col2, #T_bd82e_row46_col3, #T_bd82e_row47_col0, #T_bd82e_row47_col1, #T_bd82e_row47_col2, #T_bd82e_row47_col3, #T_bd82e_row48_col0, #T_bd82e_row48_col1, #T_bd82e_row48_col2, #T_bd82e_row48_col3, #T_bd82e_row49_col0, #T_bd82e_row49_col1, #T_bd82e_row49_col2, #T_bd82e_row49_col3, #T_bd82e_row50_col0, #T_bd82e_row50_col1, #T_bd82e_row50_col2, #T_bd82e_row50_col3, #T_bd82e_row51_col0, #T_bd82e_row51_col1, #T_bd82e_row51_col2, #T_bd82e_row51_col3, #T_bd82e_row52_col0, #T_bd82e_row52_col1, #T_bd82e_row52_col2, #T_bd82e_row52_col3, #T_bd82e_row53_col0, #T_bd82e_row53_col1, #T_bd82e_row53_col2, #T_bd82e_row53_col3, #T_bd82e_row54_col0, #T_bd82e_row54_col1, #T_bd82e_row54_col2, #T_bd82e_row54_col3, #T_bd82e_row55_col0, #T_bd82e_row55_col1, #T_bd82e_row55_col2, #T_bd82e_row55_col3, #T_bd82e_row56_col0, #T_bd82e_row56_col1, #T_bd82e_row56_col2, #T_bd82e_row56_col3, #T_bd82e_row57_col0, #T_bd82e_row57_col1, #T_bd82e_row57_col2, #T_bd82e_row57_col3, #T_bd82e_row58_col0, #T_bd82e_row58_col1, #T_bd82e_row58_col2, #T_bd82e_row58_col3, #T_bd82e_row59_col0, #T_bd82e_row59_col1, #T_bd82e_row59_col2, #T_bd82e_row59_col3, #T_bd82e_row60_col0, #T_bd82e_row60_col1, #T_bd82e_row60_col2, #T_bd82e_row60_col3, #T_bd82e_row61_col0, #T_bd82e_row61_col1, #T_bd82e_row61_col2, #T_bd82e_row61_col3, #T_bd82e_row62_col0, #T_bd82e_row62_col1, #T_bd82e_row62_col2, #T_bd82e_row62_col3, #T_bd82e_row63_col0, #T_bd82e_row63_col1, #T_bd82e_row63_col2, #T_bd82e_row63_col3, #T_bd82e_row64_col0, #T_bd82e_row64_col1, #T_bd82e_row64_col2, #T_bd82e_row64_col3, #T_bd82e_row65_col0, #T_bd82e_row65_col1, #T_bd82e_row65 ...

# %% [markdown]
# For the categories that have moved to a different topic, where did they end up?

# %%
category.style_diff(
    bl_diff.query("diff == 'moved'").sort_values(["name", "level_previous"])
)
# Out:
# <style type="text/css">
# #T_9a4dd_row0_col0, #T_9a4dd_row1_col0, #T_9a4dd_row2_col0, #T_9a4dd_row3_col0, #T_9a4dd_row4_col0, #T_9a4dd_row5_col0, #T_9a4dd_row6_col0, #T_9a4dd_row7_col0, #T_9a4dd_row8_col0, #T_9a4dd_row9_col0, #T_9a4dd_row10_col0, #T_9a4dd_row11_col0, #T_9a4dd_row12_col0, #T_9a4dd_row13_col0, #T_9a4dd_row14_col0, #T_9a4dd_row15_col0, #T_9a4dd_row16_col0, #T_9a4dd_row17_col0, #T_9a4dd_row18_col0, #T_9a4dd_row19_col0, #T_9a4dd_row20_col0, #T_9a4dd_row21_col0, #T_9a4dd_row22_col0, #T_9a4dd_row23_col0, #T_9a4dd_row24_col0, #T_9a4dd_row25_col0, #T_9a4dd_row26_col0, #T_9a4dd_row27_col0, #T_9a4dd_row28_col0, #T_9a4dd_row29_col0, #T_9a4dd_row30_col0, #T_9a4dd_row31_col0, #T_9a4dd_row32_col0, #T_9a4dd_row33_col0, #T_9a4dd_row34_col0, #T_9a4dd_row35_col0, #T_9a4dd_row36_col0, #T_9a4dd_row37_col0, #T_9a4dd_row38_col0, #T_9a4dd_row39_col0, #T_9a4dd_row40_col0, #T_9a4dd_row41_col0 {
#   background-color: cyan;
# }
# #T_9a4dd_row0_col1, #T_9a4dd_row0_col2, #T_9a4dd_row0_col3, #T_9a4dd_row2_col1, #T_9a4dd_row2_col2, #T_9a4dd_row2_col3, #T_9a4dd_row4_col1, #T_9a4dd_row4_col2, #T_9a4dd_row4_col3, #T_9a4dd_row6_col1, #T_9a4dd_row6_col2, #T_9a4dd_row6_col3, #T_9a4dd_row8_col1, #T_9a4dd_row8_col2, #T_9a4dd_row8_col3, #T_9a4dd_row10_col1, #T_9a4dd_row10_col2, #T_9a4dd_row10_col3, #T_9a4dd_row12_col1, #T_9a4dd_row12_col2, #T_9a4dd_row12_col3, #T_9a4dd_row14_col1, #T_9a4dd_row14_col2, #T_9a4dd_row14_col3, #T_9a4dd_row16_col1, #T_9a4dd_row16_col2, #T_9a4dd_row16_col3, #T_9a4dd_row18_col1, #T_9a4dd_row18_col2, #T_9a4dd_row18_col3, #T_9a4dd_row20_col1, #T_9a4dd_row20_col2, #T_9a4dd_row20_col3, #T_9a4dd_row22_col1, #T_9a4dd_row22_col2, #T_9a4dd_row22_col3, #T_9a4dd_row24_col1, #T_9a4dd_row24_col2, #T_9a4dd_row24_col3, #T_9a4dd_row26_col1, #T_9a4dd_row26_col2, #T_9a4dd_row26_col3, #T_9a4dd_row28_col1, #T_9a4dd_row28_col2, #T_9a4dd_row28_col3, #T_9a4dd_row30_col1, #T_9a4dd_row30_col2, #T_9a4dd_row30_col3, #T_9a4dd_row32_col1, #T_9a4dd_row32_col2, #T_9a4dd_row32_col3, #T_9a4dd_row34_col1, #T_9a4dd_row34_col2, #T_9a4dd_row34_col3, #T_9a4dd_row36_col1, #T_9a4dd_row36_col2, #T_9a4dd_row36_col3, #T_9a4dd_row38_col1, #T_9a4dd_row38_col2, #T_9a4dd_row38_col3, #T_9a4dd_row40_col1, #T_9a4dd_row40_col2, #T_9a4dd_row40_col3 {
#   background-color: lightsalmon;
# }
# #T_9a4dd_row1_col5, #T_9a4dd_row1_col6, #T_9a4dd_row1_col7, #T_9a4dd_row3_col5, #T_9a4dd_row3_col6, #T_9a4dd_row3_col7, #T_9a4dd_row5_col5, #T_9a4dd_row5_col6, #T_9a4dd_row5_col7, #T_9a4dd_row7_col5, #T_9a4dd_row7_col6, #T_9a4dd_row7_col7, #T_9a4dd_row9_col5, #T_9a4dd_row9_col6, #T_9a4dd_row9_col7, #T_9a4dd_row11_col5, #T_9a4dd_row11_col6, #T_9a4dd_row11_col7, #T_9a4dd_row13_col5, #T_9a4dd_row13_col6, #T_9a4dd_row13_col7, #T_9a4dd_row15_col5, #T_9a4dd_row15_col6, #T_9a4dd_row15_col7, #T_9a4dd_row17_col5, #T_9a4dd_row17_col6, #T_9a4dd_row17_col7, #T_9a4dd_row19_col5, #T_9a4dd_row19_col6, #T_9a4dd_row19_col7, #T_9a4dd_row21_col5, #T_9a4dd_row21_col6, #T_9a4dd_row21_col7, #T_9a4dd_row23_col5, #T_9a4dd_row23_col6, #T_9a4dd_row23_col7, #T_9a4dd_row25_col5, #T_9a4dd_row25_col6, #T_9a4dd_row25_col7, #T_9a4dd_row27_col5, #T_9a4dd_row27_col6, #T_9a4dd_row27_col7, #T_9a4dd_row29_col5, #T_9a4dd_row29_col6, #T_9a4dd_row29_col7, #T_9a4dd_row31_col5, #T_9a4dd_row31_col6, #T_9a4dd_row31_col7, #T_9a4dd_row33_col5, #T_9a4dd_row33_col6, #T_9a4dd_row33_col7, #T_9a4dd_row35_col5, #T_9a4dd_row35_col6, #T_9a4dd_row35_col7, #T_9a4dd_row37_col5, #T_9a4dd_row37_col6, #T_9a4dd_row37_col7, #T_9a4dd_row39_col5, #T_9a4dd_row39_col6, #T_9a4dd_row39_col7, #T_9a4dd_row41_col5, #T_9a4dd_row41_col6, #T_9a4dd_row41_col7 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9a4dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a4dd_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9a4dd_level0_col1" class="col_heading level0 col1" >seed_previous</th>
#       <th id="T_9a4dd_level0_col2" class="col_heading level0 col2" >parent_previous</th>
#       <th id="T_9a4dd_level0_col3" class="col_heading level0 col3" >level_previous</th>
#       <th id="T_9a4dd_level0_col4" class="col_heading level0 col4" >topic</th>
#       <th id="T_9a4dd_level0_col5" class="col_heading level0 col5" >seed_new</th>
#       <th id="T_9a4dd_level0_col6" class="col_heading level0 col6" >parent_new</th>
#       <th id="T_9a4dd_level0_col7" class="col_heading level0 col7" >level_new</th>
#       <th id="T_9a4dd_level0_col8" class="col_heading level0 col8" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a4dd_level0_row0" class="row_heading level0 row0" >549</th>
#       <td id="T_9a4dd_row0_col0" class="data row0 col0" >Abu Ghraib torture and prisoner abuse</td>
#       <td id="T_9a4dd_row0_col1" class="data row0 col1" >Sexual violence</td>
#       <td id="T_9a4dd_row0_col2" class="data row0 col2" >Wartime sexual violence</td>
#       <td id="T_9a4dd_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_9a4dd_row0_col4" class="data row0 col4" >sexually_explicit</td>
#       <td id="T_9a4dd_row0_col5" class="data row0 col5" >--</td>
#       <td id="T_9a4dd_row0_col6" class="data row0 col6" >--</td>
#       <td id="T_9a4dd_row0_col7" class="data row0 col7" >--</td>
#       <td id="T_9a4dd_row0_col8" class="data row0 col8" >moved</td>
#     </tr>
#     <tr>
#       <th id="T_9a4dd_level0_row1" class="row_heading level0 row1" >3386</th>
#       <td id="T_9a4dd_row1_col0" class="data row1 col0" >Abu Ghraib torture and prisoner abuse</td>
#       <td id="T_9a4dd_row1_col1" class="data row1 col1" >--</td>
#       <td id="T_9a4dd_row1_col2" class="data row1 col2" >--</td>
#       <td id="T_9a4dd_row1_col3" class="data row1 col3" >--</td>
#       <td id="T_9a4dd_row1_col4" class="data row1 col4" >cruelty</td>
#       <td id="T_9a4dd_row1_col5" class="data row1 col5" >Torture</td>
#       <td id="T_9a4dd_row1_col6" class="data row1 col6" >Torture in Iraq</td>
#       <td id="T_9a4dd_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_9a4dd_row1_col8" class="data row1 col8" >moved</td>
#     </tr>
#     <tr>
#       <th id="T_9a4dd_level0_row2" class="row_heading level0 row2" >125</th>
#       <td id="T_9a4dd_row2_col0" class="data row2 col0" >BDSM equipment</td>
#       <td id="T_9a4dd_row2_col1" class="data row2 col1" >Sex toys</td>
#       <td id="T_9a4dd_row2_col2" class="data row2 col2" >Sex toys</td>
#       <td id="T_9a4dd_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_9a4dd_row2_col4" class="data row2 col4" >sexually_explicit</td>
#       <td id="T_9a4dd_row2_col5" class="data row2 col5" >--</td>
#       <td id="T_9a4dd_row2_col6" class="data row2 col6" >--</td>
#       <td id="T_9a4dd_row2_col7" class="data row2 col7" >--</td>
#       <td id="T_9a4dd_row2_col8" class="data row2 col8" >moved</td>
#     </tr>
#     <tr>
#       <th id="T_9a4dd_level0_row3" class="row_heading level0 row3" >3385</th>
#       <td id="T_9a4dd_row3_col0" class="data row3 col0" >BDSM equipment</td>
#       <td id="T_9a4dd_row3_col1" class="data row3 col1" >--</td>
#       <td id="T_9a4dd_row3_col2" class="data row3 col2" >--</td>
#       <td id="T_9a4dd_row3_col3" class="data row3 col3" >--</td>
#       <td id="T_9a4dd_row3_col4" class="data row3 col4" >cruelty</td>
#       <td id="T_9a4dd_row3_col5" class="data row3 col5" >Torture</td>
#       <td id="T_9a4dd_row3_col6" class="data row3 col6" >Instruments of torture</td>
#       <td id="T_9a4dd_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_9a4dd_row3_col8" class="data row3 col8" >moved</td>
#     </tr>
#     <tr>
#       <th id="T_9a4dd_level0_row4" class="row_heading level0 row4" >1205</th>
#       <td id="T_9a4dd_row4_col0" class="data row4 col0" >Books about child prostitution</td>
#       <td id="T_9a4dd_row4_col1" class="data row4 col1" >Prostitution</td>
#       <td id="T_9a4dd_row4_col2" class="data row4 col2" >Books about prostitution</td>
#       <td id="T_9a4dd_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_9a4dd_row4_col4" class="data row4 col4" >sexually_explicit</td>
#       <td id="T_9a4dd_row4_col5" class="data row4 col5" >--</td>
#       <t
