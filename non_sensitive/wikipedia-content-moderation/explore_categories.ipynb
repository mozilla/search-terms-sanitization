# %% [markdown]
# # Explore the Wikipedia categories
#
# This includes some EDA to get a feel for the category dataset, and introduces some functionality for finding categories related to specific topics.
#
# This notebook requires the category index dataset to have been built previously by running `build_category_index.ipynb`.

# %%
from pathlib import Path

import pandas as pd

from wikipedia_utils.category import CategoryIndex
from wikipedia_utils.utils import display_pd

# %% [markdown]
# `DATA_DIR` should be set to the dir where the category index files were written.

# %%
DATA_DIR = "category_data"

# %% [markdown]
# ## Load the data
#
# Load the category index DF.

# %%
# CategoryIndex wraps the category index DF and provides some exploration functions.
ci = CategoryIndex(data_dir=DATA_DIR)

# %%
ci.cat_df.sample(5)
# Out:
#                                             hidden  \
# key
# Mass_media_in_Bijeljina                      False
# Russian_soups                                False
# Venezuelan_islands_of_the_Leeward_Antilles   False
# IB_Parks_%26_Entertainment                   False
# 1960_establishments_in_Southern_Rhodesia     False
#
#                                                                                   name  \
# key
# Mass_media_in_Bijeljina                                        Mass media in Bijeljina
# Russian_soups                                                            Russian soups
# Venezuelan_islands_of_the_Leeward_Antilles  Venezuelan islands of the Leeward Antilles
# IB_Parks_%26_Entertainment                                    IB Parks & Entertainment
# 1960_establishments_in_Southern_Rhodesia      1960 establishments in Southern Rhodesia
#
#                                             num_pages  num_subcats  \
# key
# Mass_media_in_Bijeljina                            15            0
# Russian_soups                                       9            0
# Venezuelan_islands_of_the_Leeward_Antilles         13            2
# IB_Parks_%26_Entertainment                          3            0
# 1960_establishments_in_Southern_Rhodesia            4            0
#
#                                                                                       parents  \
# key
# Mass_media_in_Bijeljina                     [Bijeljina, Mass_media_in_Bosnia_and_Herzegovi...
# Russian_soups                               [Commons_category_link_is_on_Wikidata, Russian...
# Venezuelan_islands_of_the_Leeward_Antilles  [Caribbean_islands_of_Venezuela, Leeward_Antil...
# IB_Parks_%26_Entertainment                  [Amusement_park_companies, Companies_based_in_...
# 1960_establishments_in_Southern_Rhodesia    [1960_establishments_by_country, 1960_establis...
#
#                                                                               parents_visible  \
# key
# Mass_media_in_Bijeljina                     [Bijeljina, Mass media in Bosnia and Herzegovi...
# Russian_soups                                             [Soups by country, Russian cuisine]
# Venezuelan_islands_of_the_Leeward_Antilles  [Leeward Antilles, Caribbean islands of Venezu...
# IB_Parks_%26_Entertainment                  [Entertainment companies of the United States,...
# 1960_establishments_in_Southern_Rhodesia    [Establishments in Southern Rhodesia by year, ...
#
#                                                                        subcats_visible
# key
# Mass_media_in_Bijeljina                                                             []
# Russian_soups                                                                       []
# Venezuelan_islands_of_the_Leeward_Antilles  [Los Roques Archipelago, Margarita Island]
# IB_Parks_%26_Entertainment                                                          []
# 1960_establishments_in_Southern_Rhodesia                                            []

# %% [markdown]
# Total number of categories:

# %%
print(f"{len(ci.cat_df):,}")
# Out:
# 2,243,956

# %% [markdown]
# ## Hidden & visible categories
#
# Some categories are "hidden", meaning that they don't show up on the Wikipedia article page. These are mainly used by editors for maintenance purposes.

# %%
ci.cat_df["hidden"].value_counts()
# Out:
# False    2210582
# True       33374
# Name: hidden, dtype: int64

# %% [markdown]
# What are the top visible & hidden categories?

# %%
ci.cat_df.query("~hidden").sort_values("num_pages", ascending=False).head(5)
# Out:
#                                      hidden  \
# key
# WikiProject_Biography_articles        False
# Biography_articles_of_living_people   False
# Living_people                         False
# Stub-Class_biography_articles         False
# Start-Class_biography_articles        False
#
#                                                                     name  \
# key
# WikiProject_Biography_articles            WikiProject Biography articles
# Biography_articles_of_living_people  Biography articles of living people
# Living_people                                              Living people
# Stub-Class_biography_articles              Stub-Class biography articles
# Start-Class_biography_articles            Start-Class biography articles
#
#                                      num_pages  num_subcats  \
# key
# WikiProject_Biography_articles         1952673            9
# Biography_articles_of_living_people    1112095            1
# Living_people                          1059265            2
# Stub-Class_biography_articles          1035116           10
# Start-Class_biography_articles          688111           10
#
#                                                                                parents  \
# key
# WikiProject_Biography_articles       [Articles_by_WikiProject, CatAutoTOC_generates...
# Biography_articles_of_living_people  [CatAutoTOC_generates_Large_category_TOC, Temp...
# Living_people                        [CatAutoTOC_generates_Large_category_TOC, Peop...
# Stub-Class_biography_articles        [Biography_articles_by_quality, CatAutoTOC_gen...
# Start-Class_biography_articles       [Biography_articles_by_quality, CatAutoTOC_gen...
#
#                                                                        parents_visible  \
# key
# WikiProject_Biography_articles        [Articles by WikiProject, WikiProject Biography]
# Biography_articles_of_living_people                   [WikiProject Biography articles]
# Living_people                                                       [People by status]
# Stub-Class_biography_articles        [Biography articles by quality, Stub-Class art...
# Start-Class_biography_articles       [Biography articles by quality, Start-Class ar...
#
#                                                                        subcats_visible
# key
# WikiProject_Biography_articles       [Automatically assessed biography articles, Bi...
# Biography_articles_of_living_people  [Biography articles of living people who have ...
# Living_people                                                 [Lists of living people]
# Stub-Class_biography_articles        [Stub-Class biography (actors and filmmakers) ...
# Start-Class_biography_articles       [Start-Class biography (actors and filmmakers)...

# %%
ci.cat_df.query("hidden").sort_values("num_pages", ascending=False).head(5)
# Out:
#                                               hidden  \
# key
# Articles_with_short_description                 True
# Short_description_is_different_from_Wikidata    True
# All_stub_articles                               True
# Noindexed_pages                                 True
# Redirects_from_moves                            True
#
#                                                                                       name  \
# key
# Articles_with_short_description                            Articles with short description
# Short_description_is_different_from_Wikidata  Short description is different from Wikidata
# All_stub_articles                                                        All stub articles
# Noindexed_pages                                                            Noindexed pages
# Redirects_from_moves                                                  Redirects from moves
#
#                                               num_pages  num_subcats  \
# key
# Articles_with_short_description                 4861387            4
# Short_description_is_different_from_Wikidata    3429523            0
# All_stub_articles                               2340123            0
# Noindexed_pages                                 2317388        51676
# Redirects_from_moves                            2173319            2
#
#                                                                                         parents  \
# key
# Articles_with_short_description               [Article_namespace_categories, CatAutoTOC_gene...
# Short_description_is_different_from_Wikidata  [Articles_with_short_description, CatAutoTOC_g...
# All_stub_articles                             [CatAutoTOC_generates_Large_category_TOC, Hidd...
# Noindexed_pages                               [CatAutoTOC_generates_Large_category_TOC, Comm...
# Redirects_from_moves                          [All_redirect_categories, CatAutoTOC_generates...
#
#                                                                                 parents_visible  \
# key
# Articles_with_short_description                                  [Article namespace categories]
# Short_description_is_different_from_Wikidata  [Wikipedia categories tracking Wikidata differ...
# All_stub_articles                                  [Stub categories, Top-level stub categories]
# Noindexed_pages                                                                              []
# Redirects_from_moves                                                                         []
#
#                                                                                 subcats_visible
# key
# Articles_with_short_description                                                              []
# Short_description_is_different_from_Wikidata                                                 []
# All_stub_articles                                                                            []
# Noindexed_pages                               [13th century of Danish law, 15th-century Moro...
# Redirects_from_moves                                                    [German female writers]

# %% [markdown]
# Some categories are "empty", meaning that they currently have no pages or subcategories. How many of these are there, counting hidden separately from visible?

# %%
(
    ci.cat_df.query("num_pages + num_subcats == 0")["hidden"].value_counts()
    .to_frame(name="n_empty")
    .rename_axis(index="hidden")
    .assign(p_empty=lambda d: d["n_empty"] / ci.cat_df["hidden"].value_counts())
)
# Out:
#         n_empty   p_empty
# hidden
# False    122704  0.055508
# True       3056  0.091568

# %% [markdown]
# How many visible categories have no visible parents (sources), subcategories (sinks/leaves), or neither?

# %%
n_parents = ci.cat_df.query("~hidden")["parents_visible"].map(len)
n_subcats = ci.cat_df.query("~hidden")["subcats_visible"].map(len)

print(f"No visible parents: {(n_parents == 0).sum():,}")
print(f"No visible subcategories: {(n_subcats == 0).sum():,}")
print(f"No visible linkage: {(n_parents + n_subcats == 0).sum():,}")
# Out:
# No visible parents: 109,162
# No visible subcategories: 1,203,132
# No visible linkage: 106,846

# %% [markdown]
# For those with no visible linkage: looking at their (hidden) parents suggests the majority of these are redirects.

# %%
(
    ci.cat_df.query("~hidden")
    [n_parents + n_subcats == 0]
    ["parents"].explode()
    .value_counts()
    .head()
)
# Out:
# Wikipedia_soft_redirected_categories    103658
# Disambiguation_categories                 2329
# CatAutoTOC_generates_no_TOC                253
# Commons_category_link_is_on_Wikidata       208
# All_redirect_categories                    139
# Name: parents, dtype: int64

# %% [markdown]
# ## Searching categories
#
# Our goal is to build a list of categories that represent NSFW topics.
# Here we show how we can explore the categories, their parents and subcategories, in order to build a list of categories for a topic at the right level of generality.
#
# In order to keep the manual curation element manageable, we are looking to choose a few broader categories to use as seeds, and then we can pull in all their subcategories automatically to make sure the topic area is well-covered. Seeds can be either exact category names which are a good match for the topic, or regexes which match categories related to the topic.
#
# This approach is used to build seed lists for the NSFW categories we wish to block. It requires some degree of manual experimentation and trial-and-error to arrive at an acceptable final list. To find examples of categories to search for, we can explore [Wikipedia's category tree](https://en.wikipedia.org/wiki/Special:CategoryTree). We can also look at the pages in Wikipedia's [objectionable content category](https://en.wikipedia.org/wiki/Category:Wikipedia_objectionable_content) to see what some common categories are that these pages belong to. Once we have some categories in mind, we can use the tools below to explore parents and subcategories to arrive at the right level of generality.

# %% [markdown]
# ### Finding matching categories
#
# First, let us look for categories relating to a general topic. We use the topic "coffee" as an example. To start with, find all categories whose name includes the word "coffee".

# %%
matching_cats = ci.find_matching_categories(regex="\\bcoffee\\b")

# %%
len(matching_cats)
# Out:
# 158

# %% [markdown]
# Take a look at some of the results. We can see that some categories are related to coffee the drink, but there are a number of others which are unrelated, eg. "Coffee County".

# %%
matching_cats_sample = matching_cats.sample(20)

# %%
# Drop index to make display more compact.
display_pd(matching_cats_sample.reset_index(drop=True))
# Out:
#                                                                  name  \
# 0                                               Coffee user templates
# 1                            Transportation in Coffee County, Georgia
# 2                          Populated places in Coffee County, Alabama
# 3                                                       Coffee portal
# 4                                      Coffee & Tea taskforce members
# 5                                       People associated with coffee
# 6                                             Coffee in North America
# 7                                               Single-serving coffee
# 8                                                    Coffee in Hawaii
# 9                                             Alcoholic coffee drinks
# 10  Transportation buildings and structures in Coffee County, Alabama
# 11                                                  Coffee softdrinks
# 12                                                 Coffee in Ethiopia
# 13                               Songs written by Clarence Coffee Jr.
# 14                                                    Coffee liqueurs
# 15                                  Great Taste Coffee Makers coaches
# 16                                      Coffee companies of Australia
# 17                                          Coffee with milk politics
# 18                                                  Coffee in Seattle
# 19                          Bodies of water of Coffee County, Georgia
#
#     num_pages  num_subcats  \
# 0          46            0
# 1          18            0
# 2           0            3
# 3          90            0
# 4           8            0
# 5           0            2
# 6           5            1
# 7           1            2
# 8           2            0
# 9          14            2
# 10          3            0
# 11          6            0
# 12          2            0
# 13         33            0
# 14          9            1
# 15          4            0
# 16          6            0
# 17          5            1
# 18         31            0
# 19          0            1
#
#                                                                                                                                                  parents_visible  \
# 0                                                      [Drink user templates, Drug user templates, Coffee and tea templates, Coffee and Tea Taskforce templates]
# 1                                                                                     [Coffee County, Georgia, Transportation in Georgia (U.S. state) by county]
# 2                                                                                   [Populated places in Alabama by county, Geography of Coffee County, Alabama]
# 3                                                                                                                                             [Beverage portals]
# 4                                                                      [Wikipedians by WikiProject, Beverages Task Force participants, Coffee and Tea Taskforce]
# 5                                                                                                                        [People associated with drinks, Coffee]
# 6                                                                                                                   [North American drinks, Coffee by continent]
# 7                                                                                                                                           [Coffee preparation]
# 8                                                                                                                           [Coffee in Oceania, Hawaiian drinks]
# 9                                                                                         [Caffeinated alcoholic drinks, Cocktails by ingredient, Coffee drinks]
# 10  [Transportation buildings and structures in Alabama by county, Buildings and structures in Coffee County, Alabama, Transportation in Coffee County, Alabama]
# 11                                                                                                                                               [Coffee drinks]
# 12                                                                                                [Agriculture in Ethiopia, Coffee by country, Coffee in Africa]
# 13                                                                                                                                         [Songs by songwriter]
# 14                                                                                                                           [Liqueurs, Alcoholic coffee drinks]
# 15                                                                                [Philippine Basketball Association coaches by club, Great Taste Coffee Makers]
# 16                                          [Drink companies of Australia, Agriculture companies of Australia, Coffee companies by country, Coffee in Australia]
# 17                                                                                                                                 [Political history of Brazil]
# 18                                                                                                             [Culture of Seattle, Coffee in the United States]
# 19                                                                      [Bodies of water of Georgia (U.S. state) by county, Landforms of Coffee County, Georgia]
#
#                                                                                                               subcats_visible  \
# 0                                                                                                                          []
# 1                                                                                                                          []
# 2   [Cities in Coffee County, Alabama, Towns in Coffee County, Alabama, Unincorporated communities in Coffee County, Alabama]
# 3                                                                                                                          []
# 4                                                                                                                          []
# 5                                                                                        [Baristas, Businesspeople in coffee]
# 6                                                                                               [Coffee in the United States]
# 7                                                            [Single-serving coffee containers, Single-serving coffee makers]
# 8                                                                                                                          []
# 9                                                                                           [Coffee liqueurs, Liqueur coffee]
# 10                                                                                                                         []
# 11                                                                                                                         []
# 12                                                                                                                         []
# 13                                                                                                                         []
# 14                                                                                            [Cocktails with coffee liqueur]
# 15                                                                                                                         []
# 16                                                                                                                         []
# 17                                                                                    [Coffee with milk politics politicians]
# 18                                                                                                                         []
# 19                                                                                         [Rivers of Coffee County, Georgia]
#
#       seed  has_parent_in_list
# 0   Coffee                True
# 1   Coffee                True
# 2   Coffee                True
# 3   Coffee               False
# 4   Coffee                True
# 5   coffee                True
# 6   Coffee                True
# 7   coffee                True
# 8   Coffee                True
# 9   coffee                True
# 10  Coffee                True
# 11  Coffee                True
# 12  Coffee                True
# 13  Coffee               False
# 14  Coffee                True
# 15  Coffee                True
# 16  Coffee                True
# 17  Coffee               False
# 18  Coffee                True
# 19  Coffee                True

# %% [markdown]
# Notice also that in many cases, both the parent and subcategory include the word "coffee", eg. "Coffee in the United States" is a subcategory of "Coffee in North America". The `has_parent_in_list` column indicates that a category has a parent which is also in this result set, ie. also matching our regex. Since we are more interested in higher-level categories, we can ignore those categories for now.

# %%
matching_cats["has_parent_in_list"].value_counts()
# Out:
# True     136
# False     22
# Name: has_parent_in_list, dtype: int64

# %% [markdown]
# This reduces the space of categories to explore.

# %%
matching_cats_noparent = matching_cats.query("~has_parent_in_list")

# %%
display_pd(matching_cats_noparent.reset_index(drop=True))
# Out:
#                                                          name  num_pages  \
# 0                                                      Coffee         14
# 1                                      Coffee County, Alabama          9
# 2                                      Coffee County, Georgia          8
# 3                                    Coffee County, Tennessee          8
# 4                                    Coffee House Press books         12
# 5                                  Coffee Stain Studios games          9
# 6                                    Coffee and Tea Taskforce          2
# 7                                    Coffee and tea templates          1
# 8                                               Coffee portal         90
# 9                                            Coffee varieties         18
# 10                                  Coffee with milk politics          5
# 11                              Ethiopian Coffee S.C. players         14
# 12                              Films scored by Masala Coffee          5
# 13                                  Great Taste Coffee Makers          9
# 14                                 Sidama Coffee S.C. players          3
# 15                       Songs written by Clarence Coffee Jr.         33
# 16      Suspected Wikipedia sockpuppets of Peanuts and Coffee          2
# 17                  Television series by Cuppa Coffee Studios         10
# 18               Wikipedia requested images of coffee and tea          8
# 19  Wikipedia requested photographs in Coffee County, Alabama          3
# 20  Wikipedia requested photographs in Coffee County, Georgia          1
# 21                  Wikipedia sockpuppets of Highlands Coffee          1
#
#     num_subcats  \
# 0            13
# 1             6
# 2             6
# 3             7
# 4             0
# 5             0
# 6             5
# 7             5
# 8             0
# 9             0
# 10            1
# 11            0
# 12            0
# 13            5
# 14            0
# 15            0
# 16            0
# 17            1
# 18            0
# 19            0
# 20            0
# 21            0
#
#                                                                  parents_visible  \
# 0                       [Individual psychoactive drugs, Drinks, Arab inventions]
# 1                                                             [Alabama counties]
# 2                                                [Georgia (U.S. state) counties]
# 3                 [Counties of Appalachia, Tennessee counties, Middle Tennessee]
# 4         [Books by publisher, Books by publishing company of the United States]
# 5                                              [Video games developed in Sweden]
# 6                                                         [Beverages Task Force]
# 7                                                              [Drink templates]
# 8                                                             [Beverage portals]
# 9                                                 [Food plant cultivars, Coffea]
# 10                                                 [Political history of Brazil]
# 11                                             [Footballers in Ethiopia by club]
# 12                   [Film scores by composer, Films scored by Indian composers]
# 13                             [Defunct Philippine Basketball Association teams]
# 14                                             [Footballers in Ethiopia by club]
# 15                                                         [Songs by songwriter]
# 16                                             [Suspected Wikipedia sockpuppets]
# 17  [Animated television series by studio, Canadian television series by studio]
# 18                                        [Wikipedia requested images of drinks]
# 19                                  [Wikipedia requested photographs in Alabama]
# 20                     [Wikipedia requested photographs in Georgia (U.S. state)]
# 21                                                       [Wikipedia sockpuppets]
#
#                                                                                                                                                                                                                                                                                      subcats_visible  \
# 0                                                 [Coffea, Coffee by continent, Coffee by country, Coffee chemistry, Coffee culture, Coffee industry, Coffee organizations, Coffee preparation, Coffee stubs, History of coffee, People associated with coffee, Types of coffee, Works about coffee]
# 1                       [Buildings and structures in Coffee County, Alabama, Education in Coffee County, Alabama, Geography of Coffee County, Alabama, National Register of Historic Places in Coffee County, Alabama, People from Coffee County, Alabama, Transportation in Coffee County, Alabama]
# 2                                        [Buildings and structures in Coffee County, Georgia, Education in Coffee County, Georgia, Geography of Coffee County, Georgia, People from Coffee County, Georgia, Tourist attractions in Coffee County, Georgia, Transportation in Coffee County, Georgia]
# 3   [Bonnaroo Music Festival, Buildings and structures in Coffee County, Tennessee, Education in Coffee County, Tennessee, Geography of Coffee County, Tennessee, People from Coffee County, Tennessee, Tourist attractions in Coffee County, Tennessee, Transportation in Coffee County, Tennessee]
# 4                                                                                                                                                                                                                                                                                                 []
# 5                                                                                                                                                                                                                                                                                                 []
# 6                                                                                                                                                                                [Coffee & Tea taskforce members, Coffee and Tea Taskforce templates, Coffee and tea logos, Coffee stubs, Tea stubs]
# 7                                                                                                                                                  [Coffee and Tea Taskforce templates, Coffee and tea navigational boxes, Coffee and tea stub templates, Coffee user templates, Tea user templates]
# 8                                                                                                                                                                                                                                                                                                 []
# 9                                                                                                                                                                                                                                                                                                 []
# 10                                                                                                                                                                                                                                                           [Coffee with milk politics politicians]
# 11                                                                                                                                                                                                                                                                                                []
# 12                                                                                                                                                                                                                                                                                                []
# 13                                                                                                                 [Great Taste Coffee Makers coaches, Great Taste Coffee Makers draft picks, Great Taste Coffee Makers games, Great Taste Coffee Makers players, Great Taste Coffee Makers seasons]
# 14                                                                                                                                                                                                                                                                                                []
# 15                                                                                                                                                                                                                                                                                                []
# 16                                                                                                                                                                                                                                                                                                []
# 17                                                                                                                                                                                                                                                                            [Celebrity Deathmatch]
# 18                                                                                                                                                                                                                                                                                                []
# 19                                                                                                                                                                                                                                                                                                []
# 20                                                                                                                                                                                                                                                                                                []
# 21                                                                                                                                                                                                                                                                                                []
#
#       seed  has_parent_in_list
# 0   Coffee               False
# 1   Coffee               False
# 2   Coffee               False
# 3   Coffee               False
# 4   Coffee               False
# 5   Coffee               False
# 6   Coffee               False
# 7   Coffee               False
# 8   Coffee               False
# 9   Coffee               False
# 10  Coffee               False
# 11  Coffee               False
# 12  Coffee               False
# 13  Coffee               False
# 14  Coffee               False
# 15  Coffee               False
# 16  Coffee               False
# 17  Coffee               False
# 18  coffee               False
# 19  Coffee               False
# 20  Coffee               False
# 21  Coffee               False

# %% [markdown]
# From here, it looks like the easiest way to build a category list for the topic "coffee" is to use a list of exact categories:
# `["Coffee", "Coffee portal", "Coffee varieties"]`.

# %% [markdown]
# ### Alternative view: flatten parents
#
# Another view which can be useful when exploring categories is to flatten out the list of parents. The parent categories can often help to provide context when a category is not immediately clear. This also shows exactly which of the parents are also in the result set.

# %%
# Pass in the result set found above
flat_parents = ci.find_parents_listed(matching_cats)

# %%
# Restrict to the categories shown in the sample above:
display_pd(flat_parents.loc[matching_cats_sample.index].reset_index(drop=True))
# Out:
#                                                                  name  \
# 0                                               Coffee user templates
# 1                                               Coffee user templates
# 2                                               Coffee user templates
# 3                                               Coffee user templates
# 4                            Transportation in Coffee County, Georgia
# 5                            Transportation in Coffee County, Georgia
# 6                          Populated places in Coffee County, Alabama
# 7                          Populated places in Coffee County, Alabama
# 8                                                       Coffee portal
# 9                                      Coffee & Tea taskforce members
# 10                                     Coffee & Tea taskforce members
# 11                                     Coffee & Tea taskforce members
# 12                                      People associated with coffee
# 13                                      People associated with coffee
# 14                                            Coffee in North America
# 15                                            Coffee in North America
# 16                                              Single-serving coffee
# 17                                                   Coffee in Hawaii
# 18                                                   Coffee in Hawaii
# 19                                            Alcoholic coffee drinks
# 20                                            Alcoholic coffee drinks
# 21                                            Alcoholic coffee drinks
# 22  Transportation buildings and structures in Coffee County, Alabama
# 23  Transportation buildings and structures in Coffee County, Alabama
# 24  Transportation buildings and structures in Coffee County, Alabama
# 25                                                  Coffee softdrinks
# 26                                                 Coffee in Ethiopia
# 27                                                 Coffee in Ethiopia
# 28                                                 Coffee in Ethiopia
# 29                               Songs written by Clarence Coffee Jr.
# 30                                                    Coffee liqueurs
# 31                                                    Coffee liqueurs
# 32                                  Great Taste Coffee Makers coaches
# 33                                  Great Taste Coffee Makers coaches
# 34                                      Coffee companies of Australia
# 35                                      Coffee companies of Australia
# 36                                      Coffee companies of Australia
# 37                                      Coffee companies of Australia
# 38                                          Coffee with milk politics
# 39                                                  Coffee in Seattle
# 40                                                  Coffee in Seattle
# 41                          Bodies of water of Coffee County, Georgia
# 42                          Bodies of water of Coffee County, Georgia
#
#                                                           parent  \
# 0                                           Drink user templates
# 1                                            Drug user templates
# 2                                       Coffee and tea templates
# 3                             Coffee and Tea Taskforce templates
# 4                                         Coffee County, Georgia
# 5               Transportation in Georgia (U.S. state) by county
# 6                          Populated places in Alabama by county
# 7                            Geography of Coffee County, Alabama
# 8                                               Beverage portals
# 9                                     Wikipedians by WikiProject
# 10                             Beverages Task Force participants
# 11                                      Coffee and Tea Taskforce
# 12                                 People associated with drinks
# 13                                                        Coffee
# 14                                         North American drinks
# 15                                           Coffee by continent
# 16                                            Coffee preparation
# 17                                             Coffee in Oceania
# 18                                               Hawaiian drinks
# 19                                  Caffeinated alcoholic drinks
# 20                                       Cocktails by ingredient
# 21                                                 Coffee drinks
# 22  Transportation buildings and structures in Alabama by county
# 23            Buildings and structures in Coffee County, Alabama
# 24                      Transportation in Coffee County, Alabama
# 25                                                 Coffee drinks
# 26                                       Agriculture in Ethiopia
# 27                                             Coffee by country
# 28                                              Coffee in Africa
# 29                                           Songs by songwriter
# 30                                                      Liqueurs
# 31                                       Alcoholic coffee drinks
# 32             Philippine Basketball Association coaches by club
# 33                                     Great Taste Coffee Makers
# 34                                  Drink companies of Australia
# 35                            Agriculture companies of Australia
# 36                                   Coffee companies by country
# 37                                           Coffee in Australia
# 38                                   Political history of Brazil
# 39                                            Culture of Seattle
# 40                                   Coffee in the United States
# 41             Bodies of water of Georgia (U.S. state) by county
# 42                           Landforms of Coffee County, Georgia
#
#     parent_in_list
# 0            False
# 1            False
# 2             True
# 3             True
# 4             True
# 5            False
# 6            False
# 7             True
# 8            False
# 9            False
# 10           False
# 11            True
# 12           False
# 13            True
# 14           False
# 15            True
# 16            True
# 17            True
# 18           False
# 19           False
# 20           False
# 21            True
# 22           False
# 23            True
# 24            True
# 25            True
# 26           False
# 27            True
# 28            True
# 29           False
# 30           False
# 31            True
# 32           False
# 33            True
# 34           False
# 35           False
# 36            True
# 37            True
# 38           False
# 39           False
# 40            True
# 41           False
# 42            True

# %% [markdown]
# For those without a parent also in the result set:

# %%
# Restrict to the categories shown in the sample above:
display_pd(flat_parents.loc[matching_cats_noparent.index].reset_index(drop=True))
# Out:
#                                                          name  \
# 0                                                      Coffee
# 1                                                      Coffee
# 2                                                      Coffee
# 3                                      Coffee County, Alabama
# 4                                      Coffee County, Georgia
# 5                                    Coffee County, Tennessee
# 6                                    Coffee County, Tennessee
# 7                                    Coffee County, Tennessee
# 8                                    Coffee House Press books
# 9                                    Coffee House Press books
# 10                                 Coffee Stain Studios games
# 11                                   Coffee and Tea Taskforce
# 12                                   Coffee and tea templates
# 13                                              Coffee portal
# 14                                           Coffee varieties
# 15                                           Coffee varieties
# 16                                  Coffee with milk politics
# 17                              Ethiopian Coffee S.C. players
# 18                              Films scored by Masala Coffee
# 19                              Films scored by Masala Coffee
# 20                                  Great Taste Coffee Makers
# 21                                 Sidama Coffee S.C. players
# 22                       Songs written by Clarence Coffee Jr.
# 23      Suspected Wikipedia sockpuppets of Peanuts and Coffee
# 24                  Television series by Cuppa Coffee Studios
# 25                  Television series by Cuppa Coffee Studios
# 26               Wikipedia requested images of coffee and tea
# 27  Wikipedia requested photographs in Coffee County, Alabama
# 28  Wikipedia requested photographs in Coffee County, Georgia
# 29                  Wikipedia sockpuppets of Highlands Coffee
#
#                                                      parent  parent_in_list
# 0                             Individual psychoactive drugs           False
# 1                                                    Drinks           False
# 2                                           Arab inventions           False
# 3                                          Alabama counties           False
# 4                             Georgia (U.S. state) counties           False
# 5                                    Counties of Appalachia           False
# 6                                        Tennessee counties           False
# 7                                          Middle Tennessee           False
# 8                                        Books by publisher           False
# 9          Books by publishing company of the United States           False
# 10                          Video games developed in Sweden           False
# 11                                     Beverages Task Force           False
# 12                                          Drink templates           False
# 13                                         Beverage portals           False
# 14                                     Food plant cultivars           False
# 15                                                   Coffea           False
# 16                              Political history of Brazil           False
# 17                          Footballers in Ethiopia by club           False
# 18                                  Film scores by composer           False
# 19                         Films scored by Indian composers           False
# 20          Defunct Philippine Basketball Association teams           False
# 21                          Footballers in Ethiopia by club           False
# 22                                      Songs by songwriter           False
# 23                          Suspected Wikipedia sockpuppets           False
# 24                     Animated television series by studio           False
# 25                     Canadian television series by studio           False
# 26                     Wikipedia requested images of drinks           False
# 27               Wikipedia requested photographs in Alabama           False
# 28  Wikipedia requested photographs in Georgia (U.S. state)           False
# 29                                    Wikipedia sockpuppets           False

# %% [markdown]
# ### Find subcategories
#
# Now that we have a seed list of higher-level categories, we can search the category index for subcategories at all levels. We will use this as our final list of categories relevant to the topic of "coffee".

# %%
seed_list = ["Coffee", "Coffee portal", "Coffee varieties"]

# %%
# Find the category listings matching this seed list.
matching_seed_cats = ci.find_matching_categories(catlist=seed_list)

# %%
display_pd(matching_seed_cats)
# Out:
#                               name  num_pages  num_subcats  \
# key
# Coffee                      Coffee         14           13
# Coffee_portal        Coffee portal         90            0
# Coffee_varieties  Coffee varieties         18            0
#
#                                                            parents_visible  \
# key
# Coffee            [Individual psychoactive drugs, Drinks, Arab inventions]
# Coffee_portal                                           [Beverage portals]
# Coffee_varieties                            [Food plant cultivars, Coffea]
#
#                                                                                                                                                                                                                                                      subcats_visible  \
# key
# Coffee            [Coffea, Coffee by continent, Coffee by country, Coffee chemistry, Coffee culture, Coffee industry, Coffee organizations, Coffee preparation, Coffee stubs, History of coffee, People associated with coffee, Types of coffee, Works about coffee]
# Coffee_portal                                                                                                                                                                                                                                                     []
# Coffee_varieties                                                                                                                                                                                                                                                  []
#
#                               seed  has_parent_in_list
# key
# Coffee                      Coffee               False
# Coffee_portal        Coffee portal               False
# Coffee_varieties  Coffee varieties               False

# %% [markdown]
# Run breadth-first search across the directed graph defined by category -> subcategory linkage to find all subcategories.

# %%
# %%time

all_cats = ci.category_bfs(matching_seed_cats)
# Out:
# CPU times: user 4.07 s, sys: 512 ms, total: 4.58 s
# Wall time: 4.69 s

# %% [markdown]
# How many categories were found?

# %%
print(f"Num categories found: {len(all_cats):,}")
print(f"Max depth reached: {all_cats['level'].max()}")
# Out:
# Num categories found: 154
# Max depth reached: 6

# %%
display_pd(all_cats)
# Out:
#                                                    name              seed  \
# 0                                                Coffee            Coffee
# 1                                         Coffee portal     Coffee portal
# 2                                      Coffee varieties  Coffee varieties
# 3                                                Coffea            Coffee
# 4                                   Coffee by continent            Coffee
# 5                                     Coffee by country            Coffee
# 6                                      Coffee chemistry            Coffee
# 7                                        Coffee culture            Coffee
# 8                                       Coffee industry            Coffee
# 9                                  Coffee organizations            Coffee
# 10                                   Coffee preparation            Coffee
# 11                                         Coffee stubs            Coffee
# 12                                    History of coffee            Coffee
# 13                        People associated with coffee            Coffee
# 14                                      Types of coffee            Coffee
# 15                                   Works about coffee            Coffee
# 16                            Coats of arms with coffea            Coffee
# 17                                     Coffee in Africa            Coffee
# 18                                       Coffee in Asia            Coffee
# 19                                     Coffee in Europe            Coffee
# 20                              Coffee in North America            Coffee
# 21                                    Coffee in Oceania            Coffee
# 22                              Coffee in South America            Coffee
# 23                          Coffee companies by country            Coffee
# 24                                  Coffee in Australia            Coffee
# 25                                    Coffee in Austria            Coffee
# 26                                   Coffee in Colombia            Coffee
# 27                                   Coffee in Ethiopia            Coffee
# 28                                    Coffee in Germany            Coffee
# 29                                     Coffee in Greece            Coffee
# 30                                      Coffee in India            Coffee
# 31                                  Coffee in Indonesia            Coffee
# 32                                      Coffee in Italy            Coffee
# 33                                   Coffee in Malaysia            Coffee
# 34                                Coffee in New Zealand            Coffee
# 35                                Coffee in South Korea            Coffee
# 36                                Coffee in Switzerland            Coffee
# 37                                     Coffee in Uganda            Coffee
# 38                                    Coffee in Vietnam            Coffee
# 39                            Coffee in the Philippines            Coffee
# 40                         Coffee in the United Kingdom            Coffee
# 41                          Coffee in the United States            Coffee
# 42                         Coffee production by country            Coffee
# 43                                             Baristas            Coffee
# 44                          Coffee culture in Australia            Coffee
# 45             Coffee culture in Bosnia and Herzegovina            Coffee
# 46                             Coffee culture in Vienna            Coffee
# 47                  Coffee culture in the United States            Coffee
# 48                                        Coffee dishes            Coffee
# 49                                        Coffee drinks            Coffee
# 50                                       Coffee museums            Coffee
# 51                                   Coffee table books            Coffee
# 52                               Coffeehouses and cafés            Coffee
# 53                             Businesspeople in coffee            Coffee
# 54                                    Coffee production            Coffee
# 55                                     Coffee companies            Coffee
# 56                             Coffee appliance vendors            Coffee
# 57                                           Coffeeware            Coffee
# 58                                    Espresso machines            Coffee
# 59                                Single-serving coffee            Coffee
# 60                                   Coffee substitutes            Coffee
# 61                                    Specialty coffees            Coffee
# 62                                   Films about coffee            Coffee
# 63                                      Coffee in Japan            Coffee
# 64                                     Coffee in Hawaii            Coffee
# 65                        Coffee companies of Australia            Coffee
# 66                          Coffee companies of Austria            Coffee
# 67                           Coffee companies of Brazil            Coffee
# 68                            Coffee companies of China            Coffee
# 69                         Coffee companies of Colombia            Coffee
# 70                           Coffee companies of Greece            Coffee
# 71                            Coffee companies of Italy            Coffee
# 72                            Coffee companies of Japan            Coffee
# 73                          Coffee companies of Vietnam            Coffee
# 74                  Coffee companies of the Philippines            Coffee
# 75               Coffee companies of the United Kingdom            Coffee
# 76                Coffee companies of the United States            Coffee
# 77                    Coffeehouses and cafés by country            Coffee
# 78                  Coffeehouses and cafés in Australia            Coffee
# 79                      Coffeehouses and cafés in India            Coffee
# 80                      Coffeehouses and cafés in Italy            Coffee
# 81                                             Espresso            Coffee
# 82                Coffeehouses and cafés in South Korea            Coffee
# 83                           Coffee in Portland, Oregon            Coffee
# 84                                    Coffee in Seattle            Coffee
# 85          Coffeehouses and cafés in the United States            Coffee
# 86                     Coffeehouses and cafés in Vienna            Coffee
# 87                              Alcoholic coffee drinks            Coffee
# 88                                   Coffee derivatives            Coffee
# 89                                    Coffee softdrinks            Coffee
# 90                                      Espresso drinks            Coffee
# 91                                         Bakery cafés            Coffee
# 92                                 Cannabis coffeeshops            Coffee
# 93                       Coffeehouses and cafés by city            Coffee
# 94   Compilation album series branded by bars and cafés            Coffee
# 95                     Fictional coffeehouses and cafés            Coffee
# 96                                       Internet cafés            Coffee
# 97                                            Starbucks            Coffee
# 98                      Types of coffeehouses and cafés            Coffee
# 99                                     Starbucks people            Coffee
# 100                                     Coffee diseases            Coffee
# 101                                       Coffee brands            Coffee
# 102                                            Bialetti            Coffee
# 103                                             Cimbali            Coffee
# 104                                           De'Longhi            Coffee
# 105                                               Faema            Coffee
# 106                                               Saeco            Coffee
# 107                    Single-serving coffee containers            Coffee
# 108                        Single-serving coffee makers            Coffee
# 109                     Coffeehouses and cafés in Japan            Coffee
# 110                     Coffeehouses and cafés in China            Coffee
# 111                    Coffeehouses and cafés in Greece            Coffee
# 112                                           Illycaffè            Coffee
# 113                                             Lavazza            Coffee
# 114                                     Massimo Zanetti            Coffee
# 115        Coffeehouses and cafés in the United Kingdom            Coffee
# 116                 Coffeehouses and cafés in Argentina            Coffee
# 117                   Coffeehouses and cafés in Austria            Coffee
# 118                    Coffeehouses and cafés in Canada            Coffee
# 119                   Coffeehouses and cafés in Denmark            Coffee
# 120                    Coffeehouses and cafés in France            Coffee
# 121                   Coffeehouses and cafés in Germany            Coffee
# 122                   Coffeehouses and cafés in Hungary            Coffee
# 123                    Coffeehouses and cafés in Israel            Coffee
# 124                  Coffeehouses and cafés in Pakistan            Coffee
# 125                    Coffeehouses and cafés in Poland            Coffee
# 126                    Coffeehouses and cafés in Russia            Coffee
# 127                 Coffeehouses and cafés in Singapore            Coffee
# 128              Coffeehouses and cafés in South Africa            Coffee
# 129                     Coffeehouses and cafés in Spain            Coffee
# 130                    Coffeehouses and cafés in Sweden            Coffee
# 131        Coffeehouses and cafés in the Czech Republic            Coffee
# 132           Coffeehouses and cafés in the Netherlands            Coffee
# 133                    Coffeehouses and cafés in Oregon            Coffee
# 134        Coffeehouses and cafés in Washington (state)            Coffee
# 135                                     GI Coffeehouses            Coffee
# 136                                     Coffee liqueurs            Coffee
# 137                                      Liqueur coffee            Coffee
# 138                                      Doughnut shops            Coffee
# 139                    Coffeehouses and cafés in Aarhus            Coffee
# 140                    Coffeehouses and cafés in Berlin            Coffee
# 141                    Coffeehouses and cafés in London            Coffee
# 142                     Coffeehouses and cafés in Paris            Coffee
# 143                        Starbucks in popular culture            Coffee
# 144                              Directors of Starbucks            Coffee
# 145                              Massimo Zanetti brands            Coffee
# 146                       Cocktails with coffee liqueur            Coffee
# 147                 Doughnut shops in the United States            Coffee
# 148                                         Tim Hortons            Coffee
# 149                                   Hear Music albums            Coffee
# 150                       Hear Music compilation albums            Coffee
# 151                              Hear Music live albums            Coffee
# 152                              Hear Music soundtracks            Coffee
# 153                             Hear Music video albums            Coffee
#
#                                           parent  level
# 0                                           None      0
# 1                                           None      0
# 2                                           None      0
# 3                                         Coffee      1
# 4                                         Coffee      1
# 5                                         Coffee      1
# 6                                         Coffee      1
# 7                                         Coffee      1
# 8                                         Coffee      1
# 9                                         Coffee      1
# 10                                        Coffee      1
# 11                                        Coffee      1
# 12                                        Coffee      1
# 13                                        Coffee      1
# 14                                        Coffee      1
# 15                                        Coffee      1
# 16                                        Coffea      2
# 17                           Coffee by continent      2
# 18                           Coffee by continent      2
# 19                           Coffee by continent      2
# 20                           Coffee by continent      2
# 21                           Coffee by continent      2
# 22                           Coffee by continent      2
# 23                             Coffee by country      2
# 24                             Coffee by country      2
# 25                             Coffee by country      2
# 26                             Coffee by country      2
# 27                             Coffee by country      2
# 28                             Coffee by country      2
# 29                             Coffee by country      2
# 30                             Coffee by country      2
# 31                             Coffee by country      2
# 32                             Coffee by country      2
# 33                             Coffee by country      2
# 34                             Coffee by country      2
# 35                             Coffee by country      2
# 36                             Coffee by country      2
# 37                             Coffee by country      2
# 38                             Coffee by country      2
# 39                             Coffee by country      2
# 40                             Coffee by country      2
# 41                             Coffee by country      2
# 42                             Coffee by country      2
# 43                                Coffee culture      2
# 44                                Coffee culture      2
# 45                                Coffee culture      2
# 46                                Coffee culture      2
# 47                                Coffee culture      2
# 48                                Coffee culture      2
# 49                                Coffee culture      2
# 50                                Coffee culture      2
# 51                                Coffee culture      2
# 52                                Coffee culture      2
# 53                               Coffee industry      2
# 54                               Coffee industry      2
# 55                          Coffee organizations      2
# 56                            Coffee preparation      2
# 57                            Coffee preparation      2
# 58                            Coffee preparation      2
# 59                            Coffee preparation      2
# 60                               Types of coffee      2
# 61                               Types of coffee      2
# 62                            Works about coffee      2
# 63                                Coffee in Asia      3
# 64                             Coffee in Oceania      3
# 65                   Coffee companies by country      3
# 66                   Coffee companies by country      3
# 67                   Coffee companies by country      3
# 68                   Coffee companies by country      3
# 69                   Coffee companies by country      3
# 70                   Coffee companies by country      3
# 71                   Coffee companies by country      3
# 72                   Coffee companies by country      3
# 73                   Coffee companies by country      3
# 74                   Coffee companies by country      3
# 75                   Coffee companies by country      3
# 76                   Coffee companies by country      3
# 77                   Coffee companies by country      3
# 78                           Coffee in Australia      3
# 79                               Coffee in India      3
# 80                               Coffee in Italy      3
# 81                               Coffee in Italy      3
# 82                         Coffee in South Korea      3
# 83                   Coffee in the United States      3
# 84                   Coffee in the United States      3
# 85                   Coffee in the United States      3
# 86                      Coffee culture in Vienna      3
# 87                                 Coffee drinks      3
# 88                                 Coffee drinks      3
# 89                                 Coffee drinks      3
# 90                                 Coffee drinks      3
# 91                        Coffeehouses and cafés      3
# 92                        Coffeehouses and cafés      3
# 93                        Coffeehouses and cafés      3
# 94                        Coffeehouses and cafés      3
# 95                        Coffeehouses and cafés      3
# 96                        Coffeehouses and cafés      3
# 97                        Coffeehouses and cafés      3
# 98                        Coffeehouses and cafés      3
# 99                      Businesspeople in coffee      3
# 100                            Coffee production      3
# 101                             Coffee companies      3
# 102                     Coffee appliance vendors      3
# 103                     Coffee appliance vendors      3
# 104                     Coffee appliance vendors      3
# 105                     Coffee appliance vendors      3
# 106                     Coffee appliance vendors      3
# 107                        Single-serving coffee      3
# 108                        Single-serving coffee      3
# 109                              Coffee in Japan      4
# 110                    Coffee companies of China      4
# 111                   Coffee companies of Greece      4
# 112                    Coffee companies of Italy      4
# 113                    Coffee companies of Italy      4
# 114                    Coffee companies of Italy      4
# 115       Coffee companies of the United Kingdom      4
# 116            Coffeehouses and cafés by country      4
# 117            Coffeehouses and cafés by country      4
# 118            Coffeehouses and cafés by country      4
# 119            Coffeehouses and cafés by country      4
# 120            Coffeehouses and cafés by country      4
# 121            Coffeehouses and cafés by country      4
# 122            Coffeehouses and cafés by country      4
# 123            Coffeehouses and cafés by country      4
# 124            Coffeehouses and cafés by country      4
# 125            Coffeehouses and cafés by country      4
# 126            Coffeehouses and cafés by country      4
# 127            Coffeehouses and cafés by country      4
# 128            Coffeehouses and cafés by country      4
# 129            Coffeehouses and cafés by country      4
# 130            Coffeehouses and cafés by country      4
# 131            Coffeehouses and cafés by country      4
# 132            Coffeehouses and cafés by country      4
# 133  Coffeehouses and cafés in the United States      4
# 134  Coffeehouses and cafés in the United States      4
# 135  Coffeehouses and cafés in the United States      4
# 136                      Alcoholic coffee drinks      4
# 137                      Alcoholic coffee drinks      4
# 138                                 Bakery cafés      4
# 139               Coffeehouses and cafés by city      4
# 140               Coffeehouses and cafés by city      4
# 141               Coffeehouses and cafés by city      4
# 142               Coffeehouses and cafés by city      4
# 143                                    Starbucks      4
# 144                             Starbucks people      4
# 145                              Massimo Zanetti      5
# 146                              Coffee liqueurs      5
# 147                               Doughnut shops      5
# 148                               Doughnut shops      5
# 149                 Starbucks in popular culture      5
# 150                            Hear Music albums      6
# 151                            Hear Music albums      6
# 152                            Hear Music albums      6
# 153                            Hear Music albums      6

# %% [markdown]
# We may decide that certain topic directions pulled in by the search are not relevant for us, such as `"Coffee culture"` and its subcategories, or all categories beyond a certain depth level. Such cases can be excluded in the BFS algorithm.
#
# It may take some trial and error to tune the list of categories as desired.

# %%
all_cats_restricted = ci.category_bfs(
    matching_seed_cats,
    ignore_cats=["Coffee culture"],
    ignore_re="coffeehouse",
    max_level=5
)
# Out:
# Level: 5

# %% [markdown]
# For this example, this will be the final list of categories relevant to the topic of "coffee":

# %%
display_pd(all_cats_restricted)
# Out:
#                                       name              seed  \
# 0                                   Coffee            Coffee
# 1                            Coffee portal     Coffee portal
# 2                         Coffee varieties  Coffee varieties
# 3                                   Coffea            Coffee
# 4                      Coffee by continent            Coffee
# 5                        Coffee by country            Coffee
# 6                         Coffee chemistry            Coffee
# 7                          Coffee industry            Coffee
# 8                     Coffee organizations            Coffee
# 9                       Coffee preparation            Coffee
# 10                            Coffee stubs            Coffee
# 11                       History of coffee            Coffee
# 12           People associated with coffee            Coffee
# 13                         Types of coffee            Coffee
# 14                      Works about coffee            Coffee
# 15               Coats of arms with coffea            Coffee
# 16                        Coffee in Africa            Coffee
# 17                          Coffee in Asia            Coffee
# 18                        Coffee in Europe            Coffee
# 19                 Coffee in North America            Coffee
# 20                       Coffee in Oceania            Coffee
# 21                 Coffee in South America            Coffee
# 22             Coffee companies by country            Coffee
# 23                     Coffee in Australia            Coffee
# 24                       Coffee in Austria            Coffee
# 25                      Coffee in Colombia            Coffee
# 26                      Coffee in Ethiopia            Coffee
# 27                       Coffee in Germany            Coffee
# 28                        Coffee in Greece            Coffee
# 29                         Coffee in India            Coffee
# 30                     Coffee in Indonesia            Coffee
# 31                         Coffee in Italy            Coffee
# 32                      Coffee in Malaysia            Coffee
# 33                   Coffee in New Zealand            Coffee
# 34                   Coffee in South Korea            Coffee
# 35                   Coffee in Switzerland            Coffee
# 36                        Coffee in Uganda            Coffee
# 37                       Coffee in Vietnam            Coffee
# 38               Coffee in the Philippines            Coffee
# 39            Coffee in the United Kingdom            Coffee
# 40             Coffee in the United States            Coffee
# 41            Coffee production by country            Coffee
# 42                Businesspeople in coffee            Coffee
# 43                       Coffee production            Coffee
# 44                        Coffee companies            Coffee
# 45                          Coffee museums            Coffee
# 46                Coffee appliance vendors            Coffee
# 47                              Coffeeware            Coffee
# 48                       Espresso machines            Coffee
# 49                   Single-serving coffee            Coffee
# 50                                Baristas            Coffee
# 51                           Coffee drinks            Coffee
# 52                      Coffee substitutes            Coffee
# 53                       Specialty coffees            Coffee
# 54                      Films about coffee            Coffee
# 55                         Coffee in Japan            Coffee
# 56                        Coffee in Hawaii            Coffee
# 57           Coffee companies of Australia            Coffee
# 58             Coffee companies of Austria            Coffee
# 59              Coffee companies of Brazil            Coffee
# 60               Coffee companies of China            Coffee
# 61            Coffee companies of Colombia            Coffee
# 62              Coffee companies of Greece            Coffee
# 63               Coffee companies of Italy            Coffee
# 64               Coffee companies of Japan            Coffee
# 65             Coffee companies of Vietnam            Coffee
# 66     Coffee companies of the Philippines            Coffee
# 67  Coffee companies of the United Kingdom            Coffee
# 68   Coffee companies of the United States            Coffee
# 69             Coffee culture in Australia            Coffee
# 70                Coffee culture in Vienna            Coffee
# 71                                Espresso            Coffee
# 72     Coffee culture in the United States            Coffee
# 73              Coffee in Portland, Oregon            Coffee
# 74                       Coffee in Seattle            Coffee
# 75                        Starbucks people            Coffee
# 76                         Coffee diseases            Coffee
# 77                           Coffee brands            Coffee
# 78                                Bialetti            Coffee
# 79                                 Cimbali            Coffee
# 80                               De'Longhi            Coffee
# 81                                   Faema            Coffee
# 82                                   Saeco            Coffee
# 83        Single-serving coffee containers            Coffee
# 84            Single-serving coffee makers            Coffee
# 85                 Alcoholic coffee drinks            Coffee
# 86                      Coffee derivatives            Coffee
# 87                       Coffee softdrinks            Coffee
# 88                         Espresso drinks            Coffee
# 89                               Illycaffè            Coffee
# 90                                 Lavazza            Coffee
# 91                         Massimo Zanetti            Coffee
# 92                  Directors of Starbucks            Coffee
# 93                               Starbucks            Coffee
# 94                         Coffee liqueurs            Coffee
# 95                          Liqueur coffee            Coffee
# 96                  Massimo Zanetti brands            Coffee
# 97            Starbucks in popular culture            Coffee
# 99           Cocktails with coffee liqueur            Coffee
#
#                            parent  level
# 0                            None      0
# 1                            None      0
# 2                            None      0
# 3                          Coffee      1
# 4                          Coffee      1
# 5                          Coffee      1
# 6                          Coffee      1
# 7                          Coffee      1
# 8                          Coffee      1
# 9                          Coffee      1
# 10                         Coffee      1
# 11                         Coffee      1
# 12                         Coffee      1
# 13                         Coffee      1
# 14                         Coffee      1
# 15                         Coffea      2
# 16            Coffee by continent      2
# 17            Coffee by continent      2
# 18            Coffee by continent      2
# 19            Coffee by continent      2
# 20            Coffee by continent      2
# 21            Coffee by continent      2
# 22              Coffee by country      2
# 23              Coffee by country      2
# 24              Coffee by country      2
# 25              Coffee by country      2
# 26              Coffee by country      2
# 27              Coffee by country      2
# 28              Coffee by country      2
# 29              Coffee by country      2
# 30              Coffee by country      2
# 31              Coffee by country      2
# 32              Coffee by country      2
# 33              Coffee by country      2
# 34              Coffee by country      2
# 35              Coffee by country      2
# 36              Coffee by country      2
# 37              Coffee by country      2
# 38              Coffee by country      2
# 39              Coffee by country      2
# 40              Coffee by country      2
# 41              Coffee by country      2
# 42                Coffee industry      2
# 43                Coffee industry      2
# 44           Coffee organizations      2
# 45           Coffee organizations      2
# 46             Coffee preparation      2
# 47             Coffee preparation      2
# 48             Coffee preparation      2
# 49             Coffee preparation      2
# 50  People associated with coffee      2
# 51                Types of coffee      2
# 52                Types of coffee      2
# 53                Types of coffee      2
# 54             Works about coffee      2
# 55                 Coffee in Asia      3
# 56              Coffee in Oceania      3
# 57    Coffee companies by country      3
# 58    Coffee companies by country      3
# 59    Coffee companies by country      3
# 60    Coffee companies by country      3
# 61    Coffee companies by country      3
# 62    Coffee companies by country      3
# 63    Coffee companies by country      3
# 64    Coffee companies by country      3
# 65    Coffee companies by country      3
# 66    Coffee companies by country      3
# 67    Coffee companies by country      3
# 68    Coffee companies by country      3
# 69            Coffee in Australia      3
# 70              Coffee in Austria      3
# 71                Coffee in Italy      3
# 72    Coffee in the United States      3
# 73    Coffee in the United States      3
# 74    Coffee in the United States      3
# 75       Businesspeople in coffee      3
# 76              Coffee production      3
# 77               Coffee companies      3
# 78       Coffee appliance vendors      3
# 79       Coffee appliance vendors      3
# 80       Coffee appliance vendors      3
# 81       Coffee appliance vendors      3
# 82       Coffee appliance vendors      3
# 83          Single-serving coffee      3
# 84          Single-serving coffee      3
# 85                  Coffee drinks      3
# 86                  Coffee drinks      3
# 87                  Coffee drinks      3
# 88                  Coffee drinks      3
# 89      Coffee companies of Italy      4
# 90      Coffee companies of Italy      4
# 91      Coffee companies of Italy      4
# 92               Starbucks people      4
# 93                  Coffee brands      4
# 94        Alcoholic coffee drinks      4
# 95        Alcoholic coffee drinks      4
# 96                Massimo Zanetti      5
# 97                      Starbucks      5
# 99                Coffee liqueurs      5
